# %% [markdown]
# # <font color="red">**Measures of Central Tendency**</font>
# - __Mean :__
# - __Median :__
# - __Mode :__

# %% [markdown]
# # <font color="red">**Measures of Dispersion(Spred)**</font>
# - __Variance :__
# - __Standard Deviation :__
# - __Range :__
# - __IQR (Interquartile Range) :__

# %% [markdown]
# # <font color="red">**Friquency and Distribution**</font>
# - __Frequency :__
# - __Relative Frequency :__
# - __Histogram/Bins :__

# %% [markdown]
# # <font color="red">**Quartiles and Percentiles**</font>
# - __Percentile :__
# - __Quartiles :__
