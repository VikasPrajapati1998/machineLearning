# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### **1. Scatterplot(Numerical- Numerical)**

# %%
plt.figure(1, figsize=(12, 8))
sns.scatterplot(data=df, x='total_bill', y='tip', color='r')
plt.figure(2, figsize=(12, 8))
sns.boxplot(data=df, y='total_bill', showmeans=True)
plt.figure(2, figsize=(12, 8))
plt.figure(3, figsize=(12, 8))
sns.violinplot(data=df, y='total_bill', color='g', inner='box', width=0.5, showmeans=True)
plt.show()

# %%
plt.figure(1, figsize=(16, 10), facecolor='aqua')
sns.scatterplot(data=df, x='total_bill', y='tip', hue='sex', size='sex', sizes=(200, 200))
plt.show()

plt.figure(2, figsize=(16, 10), facecolor='teal')
sns.scatterplot(data=df, x='total_bill', y='tip', hue='sex', style='smoker', size='sex', sizes=(200, 200))
plt.show()

plt.figure(3, figsize=(16, 10), facecolor='lime')
sns.scatterplot(data=df, x='total_bill', y='tip', hue='sex', style='smoker', size='size', sizes=(50, 200))
plt.show()

# %% [markdown]
# ### **2. Bar Plot(Numerical-Categorical)**

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df = pd.read_csv("../data/titanic/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 401         1293         0       2
# 242         1134         0       1
# 357         1249         0       3
# 356         1248         1       1
# 55           947         0       3
#
#                                                Name     Sex   Age  SibSp  \
# 401                                 Gale, Mr. Harry    male  38.0      1
# 242                    Spedden, Mr. Frederic Oakley    male  45.0      1
# 357                             Lockyer, Mr. Edward    male   NaN      0
# 356  Brown, Mrs. John Murray (Caroline Lane Lamson)  female  59.0      2
# 55                             Rice, Master. Albert    male  10.0      4
#
#      Parch  Ticket      Fare Cabin Embarked
# 401      0   28664   21.0000   NaN        S
# 242      1   16966  134.5000   E34        C
# 357      0    1222    7.8792   NaN        S
# 356      0   11769   51.4792  C101        S
# 55       1  382652   29.1250   NaN        Q

# %%
plt.figure(1, figsize=(12, 8), facecolor='olive')
sns.barplot(data=df, x='Pclass', y='Age')
plt.show()

# %%
plt.figure(1, figsize=(12, 8), facecolor='aqua')
sns.barplot(data=df, x='Pclass', y='Fare')
plt.show()

# %%
plt.figure(1, figsize=(12, 8), facecolor='olive')
sns.barplot(data=df, x='Pclass', y='Fare', hue='Sex')
plt.show()

# %% [markdown]
# ### **3. Box Plot(Numerical-Categorical)**

# %%
plt.figure(1, figsize=(12, 8), facecolor='pink')
sns.boxplot(data=df, x='Sex', y='Age', hue='Survived')
plt.show()

plt.figure(2, figsize=(12, 8), facecolor='aqua')
sns.boxplot(data=df, x='Sex', y='Age', hue='Survived', notch=True, palette='cool')
plt.show()

# %% [markdown]
# ### **4. Distplot(Numerical-Categorical)**

# %%
plt.figure(1, figsize=(12, 8), facecolor='skyblue')
sns.displot(data=df, x='Age', hue='Survived', height=12)
plt.show()

plt.figure(2, figsize=(12, 8), facecolor='skyblue')
sns.displot(data=df, x='Age', hue='Survived', height=12, kde=True)
plt.show()


plt.figure(3, figsize=(12, 8), facecolor='skyblue')
sns.displot(data=df, x='Age', hue='Survived', height=12, kind='kde')
plt.show()

# %%
plt.figure(3, figsize=(12, 8), facecolor='skyblue')
sns.displot(data=df, x='Age', hue='Survived', height=12, rug=True, kde=True)
plt.show()

# %% [markdown]
# ### **5. Heatmap(Categorical-Categorical)**

# %%
pd.crosstab(df['Pclass'], df['Survived'])
# Out:
# Survived    0   1
# Pclass
# 1          57  50
# 2          63  30
# 3         146  72

# %%
plt.figure(3, figsize=(12, 8), facecolor='skyblue')
sns.heatmap(pd.crosstab(df['Pclass'], df['Survived']), annot=True)
plt.show()

# %%
df.groupby('Pclass').mean(numeric_only=True)['Survived']*100
# Out:
# Pclass
# 1    46.728972
# 2    32.258065
# 3    33.027523
# Name: Survived, dtype: float64

# %%
(df.groupby('Pclass').mean(numeric_only=True)['Survived']*100).plot(kind='bar')
plt.show()

# %%
pd.crosstab(df['Embarked'], df['Survived'])
# Out:
# Survived    0   1
# Embarked
# C          62  40
# Q          22  24
# S         182  88

# %%
df.groupby('Embarked').mean(numeric_only=True)['Survived']*100
# Out:
# Embarked
# C    39.215686
# Q    52.173913
# S    32.592593
# Name: Survived, dtype: float64

# %%
df.groupby('Sex').mean(numeric_only=True)
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female  1096.789474       1.0  2.144737  30.272362  0.565789  0.598684
# male    1102.620301       0.0  2.334586  30.272732  0.379699  0.274436
#
#              Fare
# Sex
# female  49.747699
# male    27.527877

# %% [markdown]
# ### **6. Clustermap(Categorical - Categorical)**

# %%
pd.crosstab(df['SibSp'], df['Survived'])
# Out:
# Survived    0   1
# SibSp
# 0         195  88
# 1          56  54
# 2           8   6
# 3           3   1
# 4           3   1
# 5           0   1
# 8           1   1

# %%
sns.clustermap(pd.crosstab(df['SibSp'], df['Survived']))
plt.show()

# %% [markdown]
# ### **7. Pairplot(Numerical - Numerical)**

# %%
plt.figure(1, figsize=(12, 8))
sns.pairplot(df, hue='Survived')
plt.show()

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64
