# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## **Univariate Analysis**
# - Analysis of single columns
# - Type of data:
#   - Numerical Data : Number, Age, Salary
#   - Categorical Data : Gender, Branch, State
# - First focus on Categorical Data
# - Second focus on Numerical Data

# %%
df = pd.read_csv("../data/titanic/titanic.csv", sep=',', low_memory=False)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.shape
# Out:
# (418, 12)

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 163         1055         0       3             Pearce, Mr. Ernest    male
# 2            894         0       2      Myles, Mr. Thomas Francis    male
# 208         1100         1       1  Rosenbaum, Miss. Edith Louise  female
# 127         1019         1       3            McCoy, Miss. Alicia  female
# 223         1115         0       3  Karlsson, Mr. Einar Gervasius    male
#
#       Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 163   NaN      0      0    343271   7.0000   NaN        S
# 2    62.0      0      0    240276   9.6875   NaN        Q
# 208  33.0      0      0  PC 17613  27.7208   A11        C
# 127   NaN      2      0    367226  23.2500   NaN        Q
# 223  21.0      0      0    350053   7.7958   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# ### **Categorical Data**

# %%
plt.figure(1, figsize=(12, 8))
sns.countplot(data=df, x=df['Survived'])
plt.show()

# %%
plt.figure(1, figsize=(12, 8))
df['Survived'].value_counts().plot(kind='bar')
plt.show()

# %%
plt.figure(1, figsize=(12, 8))
sns.countplot(data=df, x='Survived')
plt.show()

# %%
plt.figure(1, figsize=(12, 8))
sns.countplot(data=df, x='Pclass')
plt.show()

# %%
plt.figure(1, figsize=(12, 8))
sns.countplot(data=df, x='Embarked')
plt.show()

# %%
plt.figure(1, figsize=(12, 8))
df['Survived'].value_counts().plot(kind='pie', autopct='%.2f', shadow=True)
plt.show()

# %%
df.Cabin.describe()
# Out:
# count                  91
# unique                 76
# top       B57 B59 B63 B66
# freq                    3
# Name: Cabin, dtype: object

# %% [markdown]
# ## **Numerical Data**

# %%
plt.figure(1, figsize=(16, 10))
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# %%
plt.figure(1, figsize=(12, 8))
sns.histplot(data=df, x='Age', kde=True)
plt.show()

# %%
plt.figure(1, figsize=(12, 8))
sns.displot(data=df, x='Age', height=12, kde=True)
plt.show()

# %%
plt.figure(1, figsize=(12, 8))
plt.subplot(1, 2, 1)
sns.boxplot(data=df, y='Age', showmeans=True)
plt.subplot(1, 2, 2)
sns.boxplot(data=df, y='Fare', color='red', showmeans=True, width=0.5, linewidth=7)
plt.show()
