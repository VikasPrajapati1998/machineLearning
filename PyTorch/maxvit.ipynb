# %%
# !pip install onnxruntime-gpu
# !pip install onnxconverter-common
# !pip install apache-tvm
# !pip install torch
# !pip install numpy
# !pip install onnxruntime
# !pip install onnx
# !pip install timm
# !pip install tqdm
# !pip install torchvision
# Out:
# Collecting onnxruntime-gpu
#   Downloading onnxruntime_gpu-1.17.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (4.3 kB)
# Collecting coloredlogs (from onnxruntime-gpu)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /opt/conda/lib/python3.10/site-packages (from onnxruntime-gpu) (23.5.26)
# Requirement already satisfied: numpy>=1.21.6 in /opt/conda/lib/python3.10/site-packages (from onnxruntime-gpu) (1.26.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from onnxruntime-gpu) (21.3)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.10/site-packages (from onnxruntime-gpu) (3.20.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from onnxruntime-gpu) (1.12)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime-gpu)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->onnxruntime-gpu) (3.1.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->onnxruntime-gpu) (1.3.0)
# Downloading onnxruntime_gpu-1.17.1-cp310-cp310-manylinux_2_28_x86_64.whl (192.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.1/192.1 MB 8.6 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.2 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.5 MB/s eta 0:00:00
# Installing collected packages: humanfriendly, coloredlogs, onnxruntime-gpu
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnxruntime-gpu-1.17.1
# Collecting onnxconverter-common
#   Downloading onnxconverter_common-1.14.0-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from onnxconverter-common) (1.26.4)
# Requirement already satisfied: onnx in /opt/conda/lib/python3.10/site-packages (from onnxconverter-common) (1.15.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from onnxconverter-common) (21.3)
# Collecting protobuf==3.20.2 (from onnxconverter-common)
#   Downloading protobuf-3.20.2-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (679 bytes)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->onnxconverter-common) (3.1.1)
# Downloading onnxconverter_common-1.14.0-py2.py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 3.0 MB/s eta 0:00:00
# Downloading protobuf-3.20.2-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 26.3 MB/s eta 0:00:00
# Installing collected packages: protobuf, onnxconverter-common
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.8.0 requires cubinlinker, which is not installed.
# cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 23.8.0 requires ptxcompiler, which is not installed.
# cuml 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.8 which is incompatible.
# apache-beam 2.46.0 requires numpy<1.25.0,>=1.14.3, but you have numpy 1.26.4 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 11.0.0 which is incompatible.
# cudf 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.4.0 which is incompatible.
# cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# cudf 23.8.0 requires protobuf<5,>=4.21, but you have protobuf 3.20.2 which is incompatible.
# cuml 23.8.0 requires dask==2023.7.1, but you have dask 2024.3.1 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2024.3.1 which is incompatible.
# dask-cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# google-cloud-aiplatform 0.6.0a1 requires google-api-core[grpc]<2.0.0dev,>=1.22.2, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-automl 1.0.1 requires google-api-core[grpc]<2.0.0dev,>=1.14.0, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-pubsub 2.19.0 requires grpcio<2.0dev,>=1.51.3, but you have grpcio 1.51.1 which is incompatible.
# kfp 2.5.0 requires google-cloud-storage<3,>=2.2.1, but you have google-cloud-storage 1.44.0 which is incompatible.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.0.5 which is incompatible.
# tensorflow 2.15.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.20.2 which is incompatible.
# tensorflow-serving-api 2.14.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.20.2 which is incompatible.
# Successfully installed onnxconverter-common-1.14.0 protobuf-3.20.2
# Collecting apache-tvm
#   Downloading apache_tvm-0.11.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.3 kB)
# Requirement already satisfied: attrs in /opt/conda/lib/python3.10/site-packages (from apache-tvm) (23.2.0)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.10/site-packages (from apache-tvm) (2.2.1)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from apache-tvm) (5.1.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from apache-tvm) (1.26.4)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from apache-tvm) (5.9.3)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from apache-tvm) (1.11.4)
# Collecting synr==0.6.0 (from apache-tvm)
#   Downloading synr-0.6.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: tornado in /opt/conda/lib/python3.10/site-packages (from apache-tvm) (6.3.3)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from apache-tvm) (4.9.0)
# Downloading apache_tvm-0.11.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (47.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 MB 34.8 MB/s eta 0:00:00
# Downloading synr-0.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: synr, apache-tvm
# Successfully installed apache-tvm-0.11.1 synr-0.6.0
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch) (2024.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (1.26.4)
# Collecting onnxruntime
#   Downloading onnxruntime-1.17.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: coloredlogs in /opt/conda/lib/python3.10/site-packages (from onnxruntime) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/conda/lib/python3.10/site-packages (from onnxruntime) (23.5.26)
# Requirement already satisfied: numpy>=1.21.6 in /opt/conda/lib/python3.10/site-packages (from onnxruntime) (1.26.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from onnxruntime) (21.3)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.10/site-packages (from onnxruntime) (3.20.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from onnxruntime) (1.12)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/conda/lib/python3.10/site-packages (from coloredlogs->onnxruntime) (10.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->onnxruntime) (3.1.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->onnxruntime) (1.3.0)
# Downloading onnxruntime-1.17.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 54.7 MB/s eta 0:00:00
# Installing collected packages: onnxruntime
# Successfully installed onnxruntime-1.17.1
# Requirement already satisfied: onnx in /opt/conda/lib/python3.10/site-packages (1.15.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from onnx) (1.26.4)
# Requirement already satisfied: protobuf>=3.20.2 in /opt/conda/lib/python3.10/site-packages (from onnx) (3.20.2)
# Requirement already satisfied: timm in /opt/conda/lib/python3.10/site-packages (0.9.16)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from timm) (2.1.2)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (from timm) (0.16.2)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from timm) (6.0.1)
# Requirement already satisfied: huggingface_hub in /opt/conda/lib/python3.10/site-packages (from timm) (0.21.4)
# Requirement already satisfied: safetensors in /opt/conda/lib/python3.10/site-packages (from timm) (0.4.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface_hub->timm) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub->timm) (2024.3.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface_hub->timm) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub->timm) (4.66.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub->timm) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub->timm) (21.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->timm) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->timm) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->timm) (3.1.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision->timm) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision->timm) (9.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->huggingface_hub->timm) (3.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->timm) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub->timm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub->timm) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub->timm) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub->timm) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->timm) (1.3.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (4.66.1)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (0.16.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from torchvision) (2.1.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (9.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (2024.2.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (2024.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->torchvision) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->torchvision) (1.3.0)

# %%
# import libraries
import os
import torch
import json
import time
from tqdm.auto import tqdm
import timm
import numpy as np
import onnxruntime as ort
from onnxruntime import quantization
from onnxconverter_common import float16
import onnx
import tvm
from tvm import relay

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device = ", device)
# Out:
# device =  cuda

# %%
def preprocess(model):
    data_config = timm.data.resolve_model_data_config(model)
    transforms = timm.data.create_transform(**data_config, is_training = False)
    print(transforms)
    
    val_dataset = timm.data.ImageDataset('/kaggle/input/imagenet/imagenet-mini', transform = transforms)
    val_loader = timm.data.create_loader(val_dataset, (1, 3, 224, 224), 1)
    
    val_dataset_sub = torch.utils.data.Subset(val_dataset, list(range(1000)))
    val_loader_sub = timm.data.create_loader(val_dataset_sub, (1, 3, 224, 224), 1)
    
    return val_loader, val_loader_sub

print("Preprocess Done ...!")
# Out:
# Preprocess Done ...!

# %%
class OnnxStaticQuantization:
    def __init__(self) -> None:
        self.enum_data = None
        self.calibration_technique = {
            "MinMax": ort.quantization.calibrate.CalibrationMethod.MinMax,
            "Entropy": ort.quantization.calibrate.CalibrationMethod.Entropy,
            "Percentile": ort.quantization.calibrate.CalibrationMethod.Percentile,
            "Distribution": ort.quantization.calibrate.CalibrationMethod.Distribution
        }

    def get_next(self, EP_list = ['CPUExecutionProvider']):
        if self.enum_data is None:
            session = ort.InferenceSession(self.fp32_onnx_path, providers = EP_list)
            input_name = session.get_inputs()[0].name
            calib_list = []
            count = 0
            for nhwc_data, _ in self.calibration_loader:
                nhwc_data=nhwc_data.cpu()
                calib_list.append({input_name: nhwc_data.numpy()}) 
                if self.sample == count: break
                count = count + 1
            self.enum_data = iter(calib_list)
        return next(self.enum_data, None)
    
    def quantization(self, fp32_onnx_path, future_int8_onnx_path, calib_method, calibration_loader, sample = 100):
        self.sample = sample
        self.calibration_loader = calibration_loader 
        _ = ort.quantization.quantize_static(
                model_input = fp32_onnx_path,
                model_output = future_int8_onnx_path,
                calibrate_method = self.calibration_technique[calib_method],
                activation_type=ort.quantization.QuantType.QInt16,
                weight_type=ort.quantization.QuantType.QInt8,
                per_channel = True, 
                reduce_range = True,
                calibration_data_reader = self
            )
        return self


print("Quantization Done ...!")
# Out:
# Quantization Done ...!

# %%
# Quantization Investigation
def quant_investigation(quant_model_name):
    _model = onnx.load(quant_model_name + ".onnx")
    initializers = _model.graph.initializer

    for node_i in _model.graph.node:
        if node_i.output and "QuantizeLinear" not in node_i.output[0] and "DequantizeLinear" not in node_i.name:
            for node_j in _model.graph.node:
                if node_j.input and node_i.output[0] == node_j.input[0] and "QuantizeLinear" not in node_j.output[0]:
                    print(node_i.name)

print("Quantization Investigation Done ...!")
# Out:
# Quantization Investigation Done ...!

# %%
def validate(model, val_loader, model_name, ONNX = False, quant = "", sample_size = 100, quant_invest = False, TVM = False):
    correct = 0
    total = 0
    elapsed_time = 0
    top5_correct = 0
    
    if ONNX:    # 1
        if not TVM:    # 2  
            if quant == "fp16":    # 3
                model = onnx.load(model_name + ".onnx")
                model_fp16 = float16.convert_float_to_float16(model)
                onnx.save(model_fp16,model_name + quant + ".onnx")
                
            elif quant == "int8":    # 3
                ort.quantization.shape_inference.quant_pre_process(model_name + ".onnx", "preprocess.onnx")
                module = OnnxStaticQuantization()
                module.fp32_onnx_path = "preprocess.onnx"
                
                module.quantization(
                    fp32_onnx_path = "preprocess.onnx",
                    future_int8_onnx_path = model_name + quant + ".onnx",
#                     calib_method = "MinMax",
#                     calib_method = "Entropy",
                    calib_method = "Percentile",
#                     calib_method = "Distribution",
                    calibration_loader = val_loader,
                    sample = sample_size
                )
                
            else:    # 3
                dummy_input = torch.randn(1, 3, 224, 224).to(device)
                torch.onnx.export(model, dummy_input, model_name + ".onnx", export_params = True, opset_version = 14, do_constant_folding = True)
                
                
        else:    # 2
            onnx_model = onnx.load(model_name + quant + ".onnx")
            shape_dict = {"input.1": (1, 3, 224, 224)}
            mod, params = relay.frontend.from_onnx(onnx_model, shape_dict)
            target = "llvm -mcpu=core-avx2"
            with tvm.transform.PassContext(opt_level = 2):
                executor = relay.build_module.create_executor("graph", mod, tvm.cpu(0), target, params).evaluate()
        
        # -------------------------------------------------------------------------------------------------------------------------
        
        sess = ort.InferenceSession(model_name + quant + ".onnx", providers = ['CPUExecutionProvider'])
        for batch_idx, (inputs, labels) in enumerate(tqdm(val_loader)):
            if quant == "fp16":
                inputs = inputs.half()
            inputs = inputs.cpu().numpy()
            
            if TVM:
                inputs = tvm.nd.array(inputs.astype("float32"))
                start_time = time.time()    
                outputs = [executor(inputs).numpy()]
                end_time = time.time()
                
            else:
                start_time = time.time()    
                outputs = sess.run(None, {sess.get_inputs()[0].name: inputs})
                end_time = time.time()
            
            elapsed_time += end_time - start_time

            predicted_labels = np.argmax(outputs[0], axis=1)

            correct += (predicted_labels == labels.cpu().numpy()).sum()
            total += labels.size(0)

            top5_predicted = np.argsort(outputs[0], axis=1)[:, -5:]  
            top5_correct += np.sum(np.equal(top5_predicted, np.expand_dims(labels.cpu().numpy(), axis=1)))
    
    
    elif ONNX == False and quant_invest == True and quant != "":    # 1
        if quant == "fp16" :
            print("fp16 quantization investigation : ")
            quant_investigation(model_name + quant)
            print()
        elif quant == "int8" :
            print("int8 quantization investigation : ")
            quant_investigation(model_name + quant)
            print()
        else :
            print("Error : quant is empty.")
        return
    
    else:  # 1
        model = model.eval()
        with torch.inference_mode():
            for batch_idx, (images, labels) in enumerate(tqdm(val_loader)):
                images, labels = images.to(device), labels.to(device)
                
                start_time = time.time()
                outputs = model(images)
                end_time = time.time()
                elapsed_time += end_time - start_time
                
                _, predicted = torch.max(outputs.softmax(dim = 1) * 100, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                _, top5_predicted = torch.topk(outputs.softmax(dim = 1) * 100, k = 5)
                top5_correct += sum(labels[i].item() in top5_predicted[i] for i in range(len(labels)))
    
    # =============================================================================================================================

    # Calculate accuracy
    single_inference_runtime = elapsed_time / total
    top1Accuracy = correct / total
    top5Accuracy = top5_correct / total
    
    print('Single Inference Runtime: {:.4f} seconds\nTop 1 Accuracy : {:.2f}%\nTop 5 Accuracy : {:.2f}%\n'.format(single_inference_runtime, 100 * top1Accuracy, 100 * top5Accuracy))


print("Validation Done ...!")
# Out:
# Validation Done ...!

# %%
# import torchvision.models as tm
# model = tm.maxvit_t('vit_base_patch16_384', pretrained=True).to(device)
# from torchvision.models import MaxVit_T_Weights
# model = timm.create_model('vit_base_patch16_384', pretrained=True).to(device)

# model load
model = timm.create_model('vit_base_patch16_224', pretrained=True).to(device)
torch.save(model.state_dict(), 'vit_base_patch16_224.pth')
print("Model Saved ...!")

val_loader, val_loader_sub = preprocess(model)
print("Data Preprocessing Done.")
# Out:
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Model Saved ...!
# Compose(
#     Resize(size=248, interpolation=bicubic, max_size=None, antialias=warn)
#     CenterCrop(size=(224, 224))
#     ToTensor()
#     Normalize(mean=tensor([0.5000, 0.5000, 0.5000]), std=tensor([0.5000, 0.5000, 0.5000]))
# )
# Data Preprocessing Done.

# %%
# Baseline Setup
validate(model, val_loader_sub, 'vit_base_patch16_224')
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Single Inference Runtime: 0.0059 seconds
# Top 1 Accuracy : 94.90%
# Top 5 Accuracy : 99.70%

# %%
# Onnx Validation
validate(model, val_loader_sub, 'vit_base_patch16_224', ONNX=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/__init__.py:1404: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert condition, message
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Single Inference Runtime: 0.2128 seconds
# Top 1 Accuracy : 94.90%
# Top 5 Accuracy : 99.70%

# %%
# Model Quantization fp16
validate(model, val_loader_sub, 'vit_base_patch16_224', ONNX=True, quant="fp16")
# Out:
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 4.487844051936918e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -3.018414318489704e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 8.422011887887493e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.5813768072803214e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -9.859419947133574e-10 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.7380121281339598e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 3.2767560366464554e-13 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.970676427227706e-13 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 5.757240018056109e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -6.758462678391197e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.1130676824677721e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -7.949734026624355e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.4130443421199743e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -3.924023417312128e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.1171264394381772e-11 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.1268688239474134e-11 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.132989251890649e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -4.646317108836229e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.903956897171156e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.249534495987973e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 4.471183956411551e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -6.721023737554788e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 9.37647826049215e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -4.459678848434123e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 4.0869934991860646e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.853400988238718e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 3.473371634754585e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -7.639854970875604e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.4279709615912e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 3.880188614857616e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.6688098014583375e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.7380031636093918e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -3.336396048325696e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 8.476831681036856e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -6.603525548598554e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 4.745515980175696e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -6.071218194847461e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 6.092477633501403e-10 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.9945332496718038e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 8.899633030523546e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.2836551377404248e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 8.35227353945811e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.8870423446060158e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 6.518845907521609e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.730953489546664e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.4775829388090642e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.621789008117048e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.3421875994245056e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.3537857057599467e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 6.702700261485006e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.533991043193964e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.34023787015758e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.3500400554185035e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.3754970495938323e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -3.2629259294481017e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.4896613720338792e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -3.837442363874288e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 6.919594852661248e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.10809172737936e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 3.585353169910377e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -9.558519309393887e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 6.843890787422424e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.9963530323584564e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 5.599304131465033e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -9.140569545706967e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.5764393285498954e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -6.062214197299909e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -7.814946911821608e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.3860585568181705e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -4.1476369005977176e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 8.537881512893364e-10 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.0580833986750804e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.6705598682165146e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -3.686500349431299e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.405510374752339e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.001421878754627e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 6.92775756760966e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -9.821746971283574e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.0828671292983927e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 6.105176453274908e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -9.422637958778068e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 6.815594133513514e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.540673449402675e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 3.864420250465628e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.160472937859595e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 6.00599605604657e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -6.373647920554504e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 4.1436123865423724e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 3.1965100788511336e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /opt/conda/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.3850020625104662e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# 2024-04-06 13:08:56.185434244 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.0/attn/Sqrt'
# 2024-04-06 13:08:56.185706000 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.1/attn/Sqrt'
# 2024-04-06 13:08:56.185950038 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.2/attn/Sqrt'
# 2024-04-06 13:08:56.186206724 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.3/attn/Sqrt'
# 2024-04-06 13:08:56.186423491 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.4/attn/Sqrt'
# 2024-04-06 13:08:56.186637530 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.5/attn/Sqrt'
# 2024-04-06 13:08:56.186899083 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.6/attn/Sqrt'
# 2024-04-06 13:08:56.187191468 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.7/attn/Sqrt'
# 2024-04-06 13:08:56.187500645 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.8/attn/Sqrt'
# 2024-04-06 13:08:56.187726688 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.9/attn/Sqrt'
# 2024-04-06 13:08:56.187962794 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.10/attn/Sqrt'
# 2024-04-06 13:08:56.188189439 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.11/attn/Sqrt'
# 2024-04-06 13:08:56.208743797 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.11/attn/Sqrt'
# 2024-04-06 13:08:56.214530612 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.11/attn/Sqrt'
# 2024-04-06 13:08:56.220323115 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.11/attn/Sqrt'
# 2024-04-06 13:08:56.226094512 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.11/attn/Sqrt'
# 2024-04-06 13:08:56.231867241 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.11/attn/Sqrt'
# 2024-04-06 13:08:56.237633406 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.11/attn/Sqrt'
# 2024-04-06 13:08:56.243414962 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.11/attn/Sqrt'
# 2024-04-06 13:08:56.249188541 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.11/attn/Sqrt'
# 2024-04-06 13:08:56.255141290 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.11/attn/Sqrt'
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Single Inference Runtime: 0.4523 seconds
# Top 1 Accuracy : 94.90%
# Top 5 Accuracy : 99.70%

# %%
# Model QDQ Investigation
validate(model, val_loader_sub, 'vit_base_patch16_224', ONNX=False, quant="fp16", quant_invest=True)
# Out:
# fp16 quantization investigation :
# /patch_embed/proj/Conv
# /patch_embed/proj/Conv
# /patch_embed/Shape
# /patch_embed/Slice
# /patch_embed/Reshape
# /Constant_1
# /Constant_2
# /ConstantOfShape
# /Equal
# /Expand
# /Concat
# /Add
# /Add
# /Add
# /blocks/blocks.0/norm1/Sub
# /blocks/blocks.0/norm1/Sub
# /blocks/blocks.0/norm1/Pow
# /blocks/blocks.0/norm1/ReduceMean_1
# /blocks/blocks.0/norm1/Add
# /blocks/blocks.0/norm1/Div
# /blocks/blocks.0/norm1/Mul
# /blocks/blocks.0/norm1/Add_1
# /blocks/blocks.0/attn/qkv/Add
# /blocks/blocks.0/attn/Reshape
# /blocks/blocks.0/attn/Transpose
# /blocks/blocks.0/attn/Split
# /blocks/blocks.0/attn/Squeeze
# /blocks/blocks.0/attn/Squeeze
# /blocks/blocks.0/attn/Squeeze_1
# /blocks/blocks.0/attn/Shape
# /blocks/blocks.0/attn/Slice
# /blocks/blocks.0/attn/Cast
# /blocks/blocks.0/attn/Constant_7
# /blocks/blocks.0/attn/Div
# /blocks/blocks.0/attn/Div
# /blocks/blocks.0/attn/Transpose_1
# /blocks/blocks.0/attn/Mul
# /blocks/blocks.0/attn/MatMul
# /blocks/blocks.0/attn/Softmax
# /blocks/blocks.0/attn/MatMul_1
# /blocks/blocks.0/attn/Transpose_2
# /blocks/blocks.0/attn/Reshape_1
# /blocks/blocks.0/Add
# /blocks/blocks.0/Add
# /blocks/blocks.0/Add
# /blocks/blocks.0/norm2/Sub
# /blocks/blocks.0/norm2/Sub
# /blocks/blocks.0/norm2/Pow
# /blocks/blocks.0/norm2/ReduceMean_1
# /blocks/blocks.0/norm2/Add
# /blocks/blocks.0/norm2/Div
# /blocks/blocks.0/norm2/Mul
# /blocks/blocks.0/norm2/Add_1
# /blocks/blocks.0/mlp/fc1/Add
# /blocks/blocks.0/mlp/fc1/Add
# /blocks/blocks.0/mlp/act/Div
# /blocks/blocks.0/mlp/act/Erf
# /blocks/blocks.0/mlp/act/Mul
# /blocks/blocks.0/mlp/act/Mul_1
# /blocks/blocks.0/Add_1
# /blocks/blocks.0/Add_1
# /blocks/blocks.0/Add_1
# /blocks/blocks.1/norm1/Sub
# /blocks/blocks.1/norm1/Sub
# /blocks/blocks.1/norm1/Pow
# /blocks/blocks.1/norm1/ReduceMean_1
# /blocks/blocks.1/norm1/Add
# /blocks/blocks.1/norm1/Div
# /blocks/blocks.1/norm1/Mul
# /blocks/blocks.1/norm1/Add_1
# /blocks/blocks.1/attn/qkv/Add
# /blocks/blocks.1/attn/Reshape
# /blocks/blocks.1/attn/Transpose
# /blocks/blocks.1/attn/Split
# /blocks/blocks.1/attn/Squeeze
# /blocks/blocks.1/attn/Squeeze
# /blocks/blocks.1/attn/Squeeze_1
# /blocks/blocks.1/attn/Shape
# /blocks/blocks.1/attn/Slice
# /blocks/blocks.1/attn/Cast
# /blocks/blocks.1/attn/Constant_7
# /blocks/blocks.1/attn/Div
# /blocks/blocks.1/attn/Div
# /blocks/blocks.1/attn/Transpose_1
# /blocks/blocks.1/attn/Mul
# /blocks/blocks.1/attn/MatMul
# /blocks/blocks.1/attn/Softmax
# /blocks/blocks.1/attn/MatMul_1
# /blocks/blocks.1/attn/Transpose_2
# /blocks/blocks.1/attn/Reshape_1
# /blocks/blocks.1/Add
# /blocks/blocks.1/Add
# /blocks/blocks.1/Add
# /blocks/blocks.1/norm2/Sub
# /blocks/blocks.1/norm2/Sub
# /blocks/blocks.1/norm2/Pow
# /blocks/blocks.1/norm2/ReduceMean_1
# /blocks/blocks.1/norm2/Add
# /blocks/blocks.1/norm2/Div
# /blocks/blocks.1/norm2/Mul
# /blocks/blocks.1/norm2/Add_1
# /blocks/blocks.1/mlp/fc1/Add
# /blocks/blocks.1/mlp/fc1/Add
# /blocks/blocks.1/mlp/act/Div
# /blocks/blocks.1/mlp/act/Erf
# /blocks/blocks.1/mlp/act/Mul
# /blocks/blocks.1/mlp/act/Mul_1
# /blocks/blocks.1/Add_1
# /blocks/blocks.1/Add_1
# /blocks/blocks.1/Add_1
# /blocks/blocks.2/norm1/Sub
# /blocks/blocks.2/norm1/Sub
# /blocks/blocks.2/norm1/Pow
# /blocks/blocks.2/norm1/ReduceMean_1
# /blocks/blocks.2/norm1/Add
# /blocks/blocks.2/norm1/Div
# /blocks/blocks.2/norm1/Mul
# /blocks/blocks.2/norm1/Add_1
# /blocks/blocks.2/attn/qkv/Add
# /blocks/blocks.2/attn/Reshape
# /blocks/blocks.2/attn/Transpose
# /blocks/blocks.2/attn/Split
# /blocks/blocks.2/attn/Squeeze
# /blocks/blocks.2/attn/Squeeze
# /blocks/blocks.2/attn/Squeeze_1
# /blocks/blocks.2/attn/Shape
# /blocks/blocks.2/attn/Slice
# /blocks/blocks.2/attn/Cast
# /blocks/blocks.2/attn/Constant_7
# /blocks/blocks.2/attn/Div
# /blocks/blocks.2/attn/Div
# /blocks/blocks.2/attn/Transpose_1
# /blocks/blocks.2/attn/Mul
# /blocks/blocks.2/attn/MatMul
# /blocks/blocks.2/attn/Softmax
# /blocks/blocks.2/attn/MatMul_1
# /blocks/blocks.2/attn/Transpose_2
# /blocks/blocks.2/attn/Reshape_1
# /blocks/blocks.2/Add
# /blocks/blocks.2/Add
# /blocks/blocks.2/Add
# /blocks/blocks.2/norm2/Sub
# /blocks/blocks.2/norm2/Sub
# /blocks/blocks.2/norm2/Pow
# /blocks/blocks.2/norm2/ReduceMean_1
# /blocks/blocks.2/norm2/Add
# /blocks/blocks.2/norm2/Div
# /blocks/blocks.2/norm2/Mul
# /blocks/blocks.2/norm2/Add_1
# /blocks/blocks.2/mlp/fc1/Add
# /blocks/blocks.2/mlp/fc1/Add
# /blocks/blocks.2/mlp/act/Div
# /blocks/blocks.2/mlp/act/Erf
# /blocks/blocks.2/mlp/act/Mul
# /blocks/blocks.2/mlp/act/Mul_1
# /blocks/blocks.2/Add_1
# /blocks/blocks.2/Add_1
# /blocks/blocks.2/Add_1
# /blocks/blocks.3/norm1/Sub
# /blocks/blocks.3/norm1/Sub
# /blocks/blocks.3/norm1/Pow
# /blocks/blocks.3/norm1/ReduceMean_1
# /blocks/blocks.3/norm1/Add
# /blocks/blocks.3/norm1/Div
# /blocks/blocks.3/norm1/Mul
# /blocks/blocks.3/norm1/Add_1
# /blocks/blocks.3/attn/qkv/Add
# /blocks/blocks.3/attn/Reshape
# /blocks/blocks.3/attn/Transpose
# /blocks/blocks.3/attn/Split
# /blocks/blocks.3/attn/Squeeze
# /blocks/blocks.3/attn/Squeeze
# /blocks/blocks.3/attn/Squeeze_1
# /blocks/blocks.3/attn/Shape
# /blocks/blocks.3/attn/Slice
# /blocks/blocks.3/attn/Cast
# /blocks/blocks.3/attn/Constant_7
# /blocks/blocks.3/attn/Div
# /blocks/blocks.3/attn/Div
# /blocks/blocks.3/attn/Transpose_1
# /blocks/blocks.3/attn/Mul
# /blocks/blocks.3/attn/MatMul
# /blocks/blocks.3/attn/Softmax
# /blocks/blocks.3/attn/MatMul_1
# /blocks/blocks.3/attn/Transpose_2
# /blocks/blocks.3/attn/Reshape_1
# /blocks/blocks.3/Add
# /blocks/blocks.3/Add
# /blocks/blocks.3/Add
# /blocks/blocks.3/norm2/Sub
# /blocks/blocks.3/norm2/Sub
# /blocks/blocks.3/norm2/Pow
# /blocks/blocks.3/norm2/ReduceMean_1
# /blocks/blocks.3/norm2/Add
# /blocks/blocks.3/norm2/Div
# /blocks/blocks.3/norm2/Mul
# /blocks/blocks.3/norm2/Add_1
# /blocks/blocks.3/mlp/fc1/Add
# /blocks/blocks.3/mlp/fc1/Add
# /blocks/blocks.3/mlp/act/Div
# /blocks/blocks.3/mlp/act/Erf
# /blocks/blocks.3/mlp/act/Mul
# /blocks/blocks.3/mlp/act/Mul_1
# /blocks/blocks.3/Add_1
# /blocks/blocks.3/Add_1
# /blocks/blocks.3/Add_1
# /blocks/blocks.4/norm1/Sub
# /blocks/blocks.4/norm1/Sub
# /blocks/blocks.4/norm1/Pow
# /blocks/blocks.4/norm1/ReduceMean_1
# /blocks/blocks.4/norm1/Add
# /blocks/blocks.4/norm1/Div
# /blocks/blocks.4/norm1/Mul
# /blocks/blocks.4/norm1/Add_1
# /blocks/blocks.4/attn/qkv/Add
# /blocks/blocks.4/attn/Reshape
# /blocks/blocks.4/attn/Transpose
# /blocks/blocks.4/attn/Split
# /blocks/blocks.4/attn/Squeeze
# /blocks/blocks.4/attn/Squeeze
# /blocks/blocks.4/attn/Squeeze_1
# /blocks/blocks.4/attn/Shape
# /blocks/blocks.4/attn/Slice
# /blocks/blocks.4/attn/Cast
# /blocks/blocks.4/attn/Constant_7
# /blocks/blocks.4/attn/Div
# /blocks/blocks.4/attn/Div
# /blocks/blocks.4/attn/Transpose_1
# /blocks/blocks.4/attn/Mul
# /blocks/blocks.4/attn/MatMul
# /blocks/blocks.4/attn/Softmax
# /blocks/blocks.4/attn/MatMul_1
# /blocks/blocks.4/attn/Transpose_2
# /blocks/blocks.4/attn/Reshape_1
# /blocks/blocks.4/Add
# /blocks/blocks.4/Add
# /blocks/blocks.4/Add
# /blocks/blocks.4/norm2/Sub
# /blocks/blocks.4/norm2/Sub
# /blocks/blocks.4/norm2/Pow
# /blocks/blocks.4/norm2/ReduceMean_1
# /blocks/blocks.4/norm2/Add
# /blocks/blocks.4/norm2/Div
# /blocks/blocks.4/norm2/Mul
# /blocks/blocks.4/norm2/Add_1
# /blocks/blocks.4/mlp/fc1/Add
# /blocks/blocks.4/mlp/fc1/Add
# /blocks/blocks.4/mlp/act/Div
# /blocks/blocks.4/mlp/act/Erf
# /blocks/blocks.4/mlp/act/Mul
# /blocks/blocks.4/mlp/act/Mul_1
# /blocks/blocks.4/Add_1
# /blocks/blocks.4/Add_1
# /blocks/blocks.4/Add_1
# /blocks/blocks.5/norm1/Sub
# /blocks/blocks.5/norm1/Sub
# /blocks/blocks.5/norm1/Pow
# /blocks/blocks.5/norm1/ReduceMean_1
# /blocks/blocks.5/norm1/Add
# /blocks/blocks.5/norm1/Div
# /blocks/blocks.5/norm1/Mul
# /blocks/blocks.5/norm1/Add_1
# /blocks/blocks.5/attn/qkv/Add
# /blocks/blocks.5/attn/Reshape
# /blocks/blocks.5/attn/Transpose
# /blocks/blocks.5/attn/Split
# /blocks/blocks.5/attn/Squeeze
# /blocks/blocks.5/attn/Squeeze
# /blocks/blocks.5/attn/Squeeze_1
# /blocks/blocks.5/attn/Shape
# /blocks/blocks.5/attn/Slice
# /blocks/blocks.5/attn/Cast
# /blocks/blocks.5/attn/Constant_7
# /blocks/blocks.5/attn/Div
# /blocks/blocks.5/attn/Div
# /blocks/blocks.5/attn/Transpose_1
# /blocks/blocks.5/attn/Mul
# /blocks/blocks.5/attn/MatMul
# /blocks/blocks.5/attn/Softmax
# /blocks/blocks.5/attn/MatMul_1
# /blocks/blocks.5/attn/Transpose_2
# /blocks/blocks.5/attn/Reshape_1
# /blocks/blocks.5/Add
# /blocks/blocks.5/Add
# /blocks/blocks.5/Add
# /blocks/blocks.5/norm2/Sub
# /blocks/blocks.5/norm2/Sub
# /blocks/blocks.5/norm2/Pow
# /blocks/blocks.5/norm2/ReduceMean_1
# /blocks/blocks.5/norm2/Add
# /blocks/blocks.5/norm2/Div
# /blocks/blocks.5/norm2/Mul
# /blocks/blocks.5/norm2/Add_1
# /blocks/blocks.5/mlp/fc1/Add
# /blocks/blocks.5/mlp/fc1/Add
# /blocks/blocks.5/mlp/act/Div
# /blocks/blocks.5/mlp/act/Erf
# /blocks/blocks.5/mlp/act/Mul
# /blocks/blocks.5/mlp/act/Mul_1
# /blocks/blocks.5/Add_1
# /blocks/blocks.5/Add_1
# /blocks/blocks.5/Add_1
# /blocks/blocks.6/norm1/Sub
# /blocks/blocks.6/norm1/Sub
# /blocks/blocks.6/norm1/Pow
# /blocks/blocks.6/norm1/ReduceMean_1
# /blocks/blocks.6/norm1/Add
# /blocks/blocks.6/norm1/Div
# /blocks/blocks.6/norm1/Mul
# /blocks/blocks.6/norm1/Add_1
# /blocks/blocks.6/attn/qkv/Add
# /blocks/blocks.6/attn/Reshape
# /blocks/blocks.6/attn/Transpose
# /blocks/blocks.6/attn/Split
# /blocks/blocks.6/attn/Squeeze
# /blocks/blocks.6/attn/Squeeze
# /blocks/blocks.6/attn/Squeeze_1
# /blocks/blocks.6/attn/Shape
# /blocks/blocks.6/attn/Slice
# /blocks/blocks.6/attn/Cast
# /blocks/blocks.6/attn/Constant_7
# /blocks/blocks.6/attn/Div
# /blocks/blocks.6/attn/Div
# /blocks/blocks.6/attn/Transpose_1
# /blocks/blocks.6/attn/Mul
# /blocks/blocks.6/attn/MatMul
# /blocks/blocks.6/attn/Softmax
# /blocks/blocks.6/attn/MatMul_1
# /blocks/blocks.6/attn/Transpose_2
# /blocks/blocks.6/attn/Reshape_1
# /blocks/blocks.6/Add
# /blocks/blocks.6/Add
# /blocks/blocks.6/Add
# /blocks/blocks.6/norm2/Sub
# /blocks/blocks.6/norm2/Sub
# /blocks/blocks.6/norm2/Pow
# /blocks/blocks.6/norm2/ReduceMean_1
# /blocks/blocks.6/norm2/Add
# /blocks/blocks.6/norm2/Div
# /blocks/blocks.6/norm2/Mul
# /blocks/blocks.6/norm2/Add_1
# /blocks/blocks.6/mlp/fc1/Add
# /blocks/blocks.6/mlp/fc1/Add
# /blocks/blocks.6/mlp/act/Div
# /blocks/blocks.6/mlp/act/Erf
# /blocks/blocks.6/mlp/act/Mul
# /blocks/blocks.6/mlp/act/Mul_1
# /blocks/blocks.6/Add_1
# /blocks/blocks.6/Add_1
# /blocks/blocks.6/Add_1
# /blocks/blocks.7/norm1/Sub
# /blocks/blocks.7/norm1/Sub
# /blocks/blocks.7/norm1/Pow
# /blocks/blocks.7/norm1/ReduceMean_1
# /blocks/blocks.7/norm1/Add
# /blocks/blocks.7/norm1/Div
# /blocks/blocks.7/norm1/Mul
# /blocks/blocks.7/norm1/Add_1
# /blocks/blocks.7/attn/qkv/Add
# /blocks/blocks.7/attn/Reshape
# /blocks/blocks.7/attn/Transpose
# /blocks/blocks.7/attn/Split
# /blocks/blocks.7/attn/Squeeze
# /blocks/blocks.7/attn/Squeeze
# /blocks/blocks.7/attn/Squeeze_1
# /blocks/blocks.7/attn/Shape
# /blocks/blocks.7/attn/Slice
# /blocks/blocks.7/attn/Cast
# /blocks/blocks.7/attn/Constant_7
# /blocks/blocks.7/attn/Div
# /blocks/blocks.7/attn/Div
# /blocks/blocks.7/attn/Transpose_1
# /blocks/blocks.7/attn/Mul
# /blocks/blocks.7/attn/MatMul
# /blocks/blocks.7/attn/Softmax
# /blocks/blocks.7/attn/MatMul_1
# /blocks/blocks.7/attn/Transpose_2
# /blocks/blocks.7/attn/Reshape_1
# /blocks/blocks.7/Add
# /blocks/blocks.7/Add
# /blocks/blocks.7/Add
# /blocks/blocks.7/norm2/Sub
# /blocks/blocks.7/norm2/Sub
# /blocks/blocks.7/norm2/Pow
# /blocks/blocks.7/norm2/ReduceMean_1
# /blocks/blocks.7/norm2/Add
# /blocks/blocks.7/norm2/Div
# /blocks/blocks.7/norm2/Mul
# /blocks/blocks.7/norm2/Add_1
# /blocks/blocks.7/mlp/fc1/Add
# /blocks/blocks.7/mlp/fc1/Add
# /blocks/blocks.7/mlp/act/Div
# /blocks/blocks.7/mlp/act/Erf
# /blocks/blocks.7/mlp/act/Mul
# /blocks/blocks.7/mlp/act/Mul_1
# /blocks/blocks.7/Add_1
# /blocks/blocks.7/Add_1
# /blocks/blocks.7/Add_1
# /blocks/blocks.8/norm1/Sub
# /blocks/blocks.8/norm1/Sub
# /blocks/blocks.8/norm1/Pow
# /blocks/blocks.8/norm1/ReduceMean_1
# /blocks/blocks.8/norm1/Add
# /blocks/blocks.8/norm1/Div
# /blocks/blocks.8/norm1/Mul
# /blocks/blocks.8/norm1/Add_1
# /blocks/blocks.8/attn/qkv/Add
# /blocks/blocks.8/attn/Reshape
# /blocks/blocks.8/attn/Transpose
# /blocks/blocks.8/attn/Split
# /blocks/blocks.8/attn/Squeeze
# /blocks/blocks.8/attn/Squeeze
# /blocks/blocks.8/attn/Squeeze_1
# /blocks/blocks.8/attn/Shape
# /blocks/blocks.8/attn/Slice
# /blocks/blocks.8/attn/Cast
# /blocks/blocks.8/attn/Constant_7
# /blocks/blocks.8/attn/Div
# /blocks/blocks.8/attn/Div
# /blocks/blocks.8/attn/Transpose_1
# /blocks/blocks.8/attn/Mul
# /blocks/blocks.8/attn/MatMul
# /blocks/blocks.8/attn/Softmax
# /blocks/blocks.8/attn/MatMul_1
# /blocks/blocks.8/attn/Transpose_2
# /blocks/blocks.8/attn/Reshape_1
# /blocks/blocks.8/Add
# /blocks/blocks.8/Add
# /blocks/blocks.8/Add
# /blocks/blocks.8/norm2/Sub
# /blocks/blocks.8/norm2/Sub
# /blocks/blocks.8/norm2/Pow
# /blocks/blocks.8/norm2/ReduceMean_1
# /blocks/blocks.8/norm2/Add
# /blocks/blocks.8/norm2/Div
# /blocks/blocks.8/norm2/Mul
# /blocks/blocks.8/norm2/Add_1
# /blocks/blocks.8/mlp/fc1/Add
# /blocks/blocks.8/mlp/fc1/Add
# /blocks/blocks.8/mlp/act/Div
# /blocks/blocks.8/mlp/act/Erf
# /blocks/blocks.8/mlp/act/Mul
# /blocks/blocks.8/mlp/act/Mul_1
# /blocks/blocks.8/Add_1
# /blocks/blocks.8/Add_1
# /blocks/blocks.8/Add_1
# /blocks/blocks.9/norm1/Sub
# /blocks/blocks.9/norm1/Sub
# /blocks/blocks.9/norm1/Pow
# /blocks/blocks.9/norm1/ReduceMean_1
# /blocks/blocks.9/norm1/Add
# /blocks/blocks.9/norm1/Div
# /blocks/blocks.9/norm1/Mul
# /blocks/blocks.9/norm1/Add_1
# /blocks/blocks.9/attn/qkv/Add
# /blocks/blocks.9/attn/Reshape
# /blocks/blocks.9/attn/Transpose
# /blocks/blocks.9/attn/Split
# /blocks/blocks.9/attn/Squeeze
# /blocks/blocks.9/attn/Squeeze
# /blocks/blocks.9/attn/Squeeze_1
# /blocks/blocks.9/attn/Shape
# /blocks/blocks.9/attn/Slice
# /blocks/blocks.9/attn/Cast
# /blocks/blocks.9/attn/Constant_7
# /blocks/blocks.9/attn/Div
# /blocks/blocks.9/attn/Div
# /blocks/blocks.9/attn/Transpose_1
# /blocks/blocks.9/attn/Mul
# /blocks/blocks.9/attn/MatMul
# /blocks/blocks.9/attn/Softmax
# /blocks/blocks.9/attn/MatMul_1
# /blocks/blocks.9/attn/Transpose_2
# /blocks/blocks.9/attn/Reshape_1
# /blocks/blocks.9/Add
# /blocks/blocks.9/Add
# /blocks/blocks.9/Add
# /blocks/blocks.9/norm2/Sub
# /blocks/blocks.9/norm2/Sub
# /blocks/blocks.9/norm2/Pow
# /blocks/blocks.9/norm2/ReduceMean_1
# /blocks/blocks.9/norm2/Add
# /blocks/blocks.9/norm2/Div
# /blocks/blocks.9/norm2/Mul
# /blocks/blocks.9/norm2/Add_1
# /blocks/blocks.9/mlp/fc1/Add
# /blocks/blocks.9/mlp/fc1/Add
# /blocks/blocks.9/mlp/act/Div
# /blocks/blocks.9/mlp/act/Erf
# /blocks/blocks.9/mlp/act/Mul
# /blocks/blocks.9/mlp/act/Mul_1
# /blocks/blocks.9/Add_1
# /blocks/blocks.9/Add_1
# /blocks/blocks.9/Add_1
# /blocks/blocks.10/norm1/Sub
# /blocks/blocks.10/norm1/Sub
# /blocks/blocks.10/norm1/Pow
# /blocks/blocks.10/norm1/ReduceMean_1
# /blocks/blocks.10/norm1/Add
# /blocks/blocks.10/norm1/Div
# /blocks/blocks.10/norm1/Mul
# /blocks/blocks.10/norm1/Add_1
# /blocks/blocks.10/attn/qkv/Add
# /blocks/blocks.10/attn/Reshape
# /blocks/blocks.10/attn/Transpose
# /blocks/blocks.10/attn/Split
# /blocks/blocks.10/attn/Squeeze
# /blocks/blocks.10/attn/Squeeze
# /blocks/blocks.10/attn/Squeeze_1
# /blocks/blocks.10/attn/Shape
# /blocks/blocks.10/attn/Slice
# /blocks/blocks.10/attn/Cast
# /blocks/blocks.10/attn/Constant_7
# /blocks/blocks.10/attn/Div
# /blocks/blocks.10/attn/Div
# /blocks/blocks.10/attn/Transpose_1
# /blocks/blocks.10/attn/Mul
# /blocks/blocks.10/attn/MatMul
# /blocks/blocks.10/attn/Softmax
# /blocks/blocks.10/attn/MatMul_1
# /blocks/blocks.10/attn/Transpose_2
# /blocks/blocks.10/attn/Reshape_1
# /blocks/blocks.10/Add
# /blocks/blocks.10/Add
# /blocks/blocks.10/Add
# /blocks/blocks.10/norm2/Sub
# /blocks/blocks.10/norm2/Sub
# /blocks/blocks.10/norm2/Pow
# /blocks/blocks.10/norm2/ReduceMean_1
# /blocks/blocks.10/norm2/Add
# /blocks/blocks.10/norm2/Div
# /blocks/blocks.10/norm2/Mul
# /blocks/blocks.10/norm2/Add_1
# /blocks/blocks.10/mlp/fc1/Add
# /blocks/blocks.10/mlp/fc1/Add
# /blocks/blocks.10/mlp/act/Div
# /blocks/blocks.10/mlp/act/Erf
# /blocks/blocks.10/mlp/act/Mul
# /blocks/blocks.10/mlp/act/Mul_1
# /blocks/blocks.10/Add_1
# /blocks/blocks.10/Add_1
# /blocks/blocks.10/Add_1
# /blocks/blocks.11/norm1/Sub
# /blocks/blocks.11/norm1/Sub
# /blocks/blocks.11/norm1/Pow
# /blocks/blocks.11/norm1/ReduceMean_1
# /blocks/blocks.11/norm1/Add
# /blocks/blocks.11/norm1/Div
# /blocks/blocks.11/norm1/Mul
# /blocks/blocks.11/norm1/Add_1
# /blocks/blocks.11/attn/qkv/Add
# /blocks/blocks.11/attn/Reshape
# /blocks/blocks.11/attn/Transpose
# /blocks/blocks.11/attn/Split
# /blocks/blocks.11/attn/Squeeze
# /blocks/blocks.11/attn/Squeeze
# /blocks/blocks.11/attn/Squeeze_1
# /blocks/blocks.11/attn/Shape
# /blocks/blocks.11/attn/Slice
# /blocks/blocks.11/attn/Cast
# /blocks/blocks.11/attn/Constant_7
# /blocks/blocks.11/attn/Div
# /blocks/blocks.11/attn/Div
# /blocks/blocks.11/attn/Transpose_1
# /blocks/blocks.11/attn/Mul
# /blocks/blocks.11/attn/MatMul
# /blocks/blocks.11/attn/Softmax
# /blocks/blocks.11/attn/MatMul_1
# /blocks/blocks.11/attn/Transpose_2
# /blocks/blocks.11/attn/Reshape_1
# /blocks/blocks.11/Add
# /blocks/blocks.11/Add
# /blocks/blocks.11/Add
# /blocks/blocks.11/norm2/Sub
# /blocks/blocks.11/norm2/Sub
# /blocks/blocks.11/norm2/Pow
# /blocks/blocks.11/norm2/ReduceMean_1
# /blocks/blocks.11/norm2/Add
# /blocks/blocks.11/norm2/Div
# /blocks/blocks.11/norm2/Mul
# /blocks/blocks.11/norm2/Add_1
# /blocks/blocks.11/mlp/fc1/Add
# /blocks/blocks.11/mlp/fc1/Add
# /blocks/blocks.11/mlp/act/Div
# /blocks/blocks.11/mlp/act/Erf
# /blocks/blocks.11/mlp/act/Mul
# /blocks/blocks.11/mlp/act/Mul_1
# /blocks/blocks.11/Add_1
# /blocks/blocks.11/Add_1
# /norm/Sub
# /norm/Sub
# /norm/Pow
# /norm/ReduceMean_1
# /norm/Add
# /norm/Div
# /norm/Mul
# /norm/Add_1
# /Gather

# %%
# Model Quantization int8
validate(model, val_loader_sub, 'vit_base_patch16_224', ONNX=True, sample_size=50, quant="int8")
# Out:
# Collecting tensor data and making histogram ...
# Finding optimal threshold for each tensor using 'percentile' algorithm ...
# Number of tensors : 505
# Number of histogram bins : 2048
# Percentile : (0.0010000000000047748,99.999)
# /opt/conda/lib/python3.10/site-packages/onnxruntime/quantization/onnx_quantizer.py:919: RuntimeWarning: invalid value encountered in cast
#   quantized_data = (np.asarray(bias_data) / bias_scale).round().astype(np.int32)
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Single Inference Runtime: 0.5787 seconds
# Top 1 Accuracy : 87.00%
# Top 5 Accuracy : 96.60%

# %%
# Model QDQ Investigation
validate(model, val_loader_sub, 'vit_base_patch16_224', ONNX=False, quant="int8", quant_invest=True)
# Out:
# int8 quantization investigation :
# /blocks/blocks.0/norm1/Sub
# /blocks/blocks.0/norm1/Sub
# /blocks/blocks.0/norm1/Pow
# /blocks/blocks.0/norm2/Sub
# /blocks/blocks.0/norm2/Sub
# /blocks/blocks.0/norm2/Pow
# /blocks/blocks.0/mlp/act/Div
# /blocks/blocks.1/norm1/Sub
# /blocks/blocks.1/norm1/Sub
# /blocks/blocks.1/norm1/Pow
# /blocks/blocks.1/norm2/Sub
# /blocks/blocks.1/norm2/Sub
# /blocks/blocks.1/norm2/Pow
# /blocks/blocks.1/mlp/act/Div
# /blocks/blocks.2/norm1/Sub
# /blocks/blocks.2/norm1/Sub
# /blocks/blocks.2/norm1/Pow
# /blocks/blocks.2/norm2/Sub
# /blocks/blocks.2/norm2/Sub
# /blocks/blocks.2/norm2/Pow
# /blocks/blocks.2/mlp/act/Div
# /blocks/blocks.3/norm1/Sub
# /blocks/blocks.3/norm1/Sub
# /blocks/blocks.3/norm1/Pow
# /blocks/blocks.3/norm2/Sub
# /blocks/blocks.3/norm2/Sub
# /blocks/blocks.3/norm2/Pow
# /blocks/blocks.3/mlp/act/Div
# /blocks/blocks.4/norm1/Sub
# /blocks/blocks.4/norm1/Sub
# /blocks/blocks.4/norm1/Pow
# /blocks/blocks.4/norm2/Sub
# /blocks/blocks.4/norm2/Sub
# /blocks/blocks.4/norm2/Pow
# /blocks/blocks.4/mlp/act/Div
# /blocks/blocks.5/norm1/Sub
# /blocks/blocks.5/norm1/Sub
# /blocks/blocks.5/norm1/Pow
# /blocks/blocks.5/norm2/Sub
# /blocks/blocks.5/norm2/Sub
# /blocks/blocks.5/norm2/Pow
# /blocks/blocks.5/mlp/act/Div
# /blocks/blocks.6/norm1/Sub
# /blocks/blocks.6/norm1/Sub
# /blocks/blocks.6/norm1/Pow
# /blocks/blocks.6/norm2/Sub
# /blocks/blocks.6/norm2/Sub
# /blocks/blocks.6/norm2/Pow
# /blocks/blocks.6/mlp/act/Div
# /blocks/blocks.7/norm1/Sub
# /blocks/blocks.7/norm1/Sub
# /blocks/blocks.7/norm1/Pow
# /blocks/blocks.7/norm2/Sub
# /blocks/blocks.7/norm2/Sub
# /blocks/blocks.7/norm2/Pow
# /blocks/blocks.7/mlp/act/Div
# /blocks/blocks.8/norm1/Sub
# /blocks/blocks.8/norm1/Sub
# /blocks/blocks.8/norm1/Pow
# /blocks/blocks.8/norm2/Sub
# /blocks/blocks.8/norm2/Sub
# /blocks/blocks.8/norm2/Pow
# /blocks/blocks.8/mlp/act/Div
# /blocks/blocks.9/norm1/Sub
# /blocks/blocks.9/norm1/Sub
# /blocks/blocks.9/norm1/Pow
# /blocks/blocks.9/norm2/Sub
# /blocks/blocks.9/norm2/Sub
# /blocks/blocks.9/norm2/Pow
# /blocks/blocks.9/mlp/act/Div
# /blocks/blocks.10/norm1/Sub
# /blocks/blocks.10/norm1/Sub
# /blocks/blocks.10/norm1/Pow
# /blocks/blocks.10/norm2/Sub
# /blocks/blocks.10/norm2/Sub
# /blocks/blocks.10/norm2/Pow
# /blocks/blocks.10/mlp/act/Div
# /blocks/blocks.11/norm1/Sub
# /blocks/blocks.11/norm1/Sub
# /blocks/blocks.11/norm1/Pow
# /blocks/blocks.11/norm2/Sub
# /blocks/blocks.11/norm2/Sub
# /blocks/blocks.11/norm2/Pow
# /blocks/blocks.11/mlp/act/Div
# /norm/Sub
# /norm/Sub
# /norm/Pow

# %%
# Quantization Investigation
import onnx

def quant_investigation(quant_model_name):
    _model = onnx.load(quant_model_name + ".onnx")
    initializers = _model.graph.initializer

    for node_i in _model.graph.node:
        if node_i.output and "QuantizeLinear" not in node_i.output[0] and "DequantizeLinear" not in node_i.name:
            for node_j in _model.graph.node:
                if node_j.input and node_i.output[0] == node_j.input[0] and "QuantizeLinear" not in node_j.output[0]:
                    print(node_i.name)

print("fp16 quantization investigation : ")
quant_investigation("vit_base_patch16_224fp16")
print()
# Out:
# fp16 quantization investigation :
# /patch_embed/proj/Conv
# /patch_embed/proj/Conv
# /patch_embed/Shape
# /patch_embed/Slice
# /patch_embed/Reshape
# /Constant_1
# /Constant_2
# /ConstantOfShape
# /Equal
# /Expand
# /Concat
# /Add
# /Add
# /Add
# /blocks/blocks.0/norm1/Sub
# /blocks/blocks.0/norm1/Sub
# /blocks/blocks.0/norm1/Pow
# /blocks/blocks.0/norm1/ReduceMean_1
# /blocks/blocks.0/norm1/Add
# /blocks/blocks.0/norm1/Div
# /blocks/blocks.0/norm1/Mul
# /blocks/blocks.0/norm1/Add_1
# /blocks/blocks.0/attn/qkv/Add
# /blocks/blocks.0/attn/Reshape
# /blocks/blocks.0/attn/Transpose
# /blocks/blocks.0/attn/Split
# /blocks/blocks.0/attn/Squeeze
# /blocks/blocks.0/attn/Squeeze
# /blocks/blocks.0/attn/Squeeze_1
# /blocks/blocks.0/attn/Shape
# /blocks/blocks.0/attn/Slice
# /blocks/blocks.0/attn/Cast
# /blocks/blocks.0/attn/Constant_7
# /blocks/blocks.0/attn/Div
# /blocks/blocks.0/attn/Div
# /blocks/blocks.0/attn/Transpose_1
# /blocks/blocks.0/attn/Mul
# /blocks/blocks.0/attn/MatMul
# /blocks/blocks.0/attn/Softmax
# /blocks/blocks.0/attn/MatMul_1
# /blocks/blocks.0/attn/Transpose_2
# /blocks/blocks.0/attn/Reshape_1
# /blocks/blocks.0/Add
# /blocks/blocks.0/Add
# /blocks/blocks.0/Add
# /blocks/blocks.0/norm2/Sub
# /blocks/blocks.0/norm2/Sub
# /blocks/blocks.0/norm2/Pow
# /blocks/blocks.0/norm2/ReduceMean_1
# /blocks/blocks.0/norm2/Add
# /blocks/blocks.0/norm2/Div
# /blocks/blocks.0/norm2/Mul
# /blocks/blocks.0/norm2/Add_1
# /blocks/blocks.0/mlp/fc1/Add
# /blocks/blocks.0/mlp/fc1/Add
# /blocks/blocks.0/mlp/act/Div
# /blocks/blocks.0/mlp/act/Erf
# /blocks/blocks.0/mlp/act/Mul
# /blocks/blocks.0/mlp/act/Mul_1
# /blocks/blocks.0/Add_1
# /blocks/blocks.0/Add_1
# /blocks/blocks.0/Add_1
# /blocks/blocks.1/norm1/Sub
# /blocks/blocks.1/norm1/Sub
# /blocks/blocks.1/norm1/Pow
# /blocks/blocks.1/norm1/ReduceMean_1
# /blocks/blocks.1/norm1/Add
# /blocks/blocks.1/norm1/Div
# /blocks/blocks.1/norm1/Mul
# /blocks/blocks.1/norm1/Add_1
# /blocks/blocks.1/attn/qkv/Add
# /blocks/blocks.1/attn/Reshape
# /blocks/blocks.1/attn/Transpose
# /blocks/blocks.1/attn/Split
# /blocks/blocks.1/attn/Squeeze
# /blocks/blocks.1/attn/Squeeze
# /blocks/blocks.1/attn/Squeeze_1
# /blocks/blocks.1/attn/Shape
# /blocks/blocks.1/attn/Slice
# /blocks/blocks.1/attn/Cast
# /blocks/blocks.1/attn/Constant_7
# /blocks/blocks.1/attn/Div
# /blocks/blocks.1/attn/Div
# /blocks/blocks.1/attn/Transpose_1
# /blocks/blocks.1/attn/Mul
# /blocks/blocks.1/attn/MatMul
# /blocks/blocks.1/attn/Softmax
# /blocks/blocks.1/attn/MatMul_1
# /blocks/blocks.1/attn/Transpose_2
# /blocks/blocks.1/attn/Reshape_1
# /blocks/blocks.1/Add
# /blocks/blocks.1/Add
# /blocks/blocks.1/Add
# /blocks/blocks.1/norm2/Sub
# /blocks/blocks.1/norm2/Sub
# /blocks/blocks.1/norm2/Pow
# /blocks/blocks.1/norm2/ReduceMean_1
# /blocks/blocks.1/norm2/Add
# /blocks/blocks.1/norm2/Div
# /blocks/blocks.1/norm2/Mul
# /blocks/blocks.1/norm2/Add_1
# /blocks/blocks.1/mlp/fc1/Add
# /blocks/blocks.1/mlp/fc1/Add
# /blocks/blocks.1/mlp/act/Div
# /blocks/blocks.1/mlp/act/Erf
# /blocks/blocks.1/mlp/act/Mul
# /blocks/blocks.1/mlp/act/Mul_1
# /blocks/blocks.1/Add_1
# /blocks/blocks.1/Add_1
# /blocks/blocks.1/Add_1
# /blocks/blocks.2/norm1/Sub
# /blocks/blocks.2/norm1/Sub
# /blocks/blocks.2/norm1/Pow
# /blocks/blocks.2/norm1/ReduceMean_1
# /blocks/blocks.2/norm1/Add
# /blocks/blocks.2/norm1/Div
# /blocks/blocks.2/norm1/Mul
# /blocks/blocks.2/norm1/Add_1
# /blocks/blocks.2/attn/qkv/Add
# /blocks/blocks.2/attn/Reshape
# /blocks/blocks.2/attn/Transpose
# /blocks/blocks.2/attn/Split
# /blocks/blocks.2/attn/Squeeze
# /blocks/blocks.2/attn/Squeeze
# /blocks/blocks.2/attn/Squeeze_1
# /blocks/blocks.2/attn/Shape
# /blocks/blocks.2/attn/Slice
# /blocks/blocks.2/attn/Cast
# /blocks/blocks.2/attn/Constant_7
# /blocks/blocks.2/attn/Div
# /blocks/blocks.2/attn/Div
# /blocks/blocks.2/attn/Transpose_1
# /blocks/blocks.2/attn/Mul
# /blocks/blocks.2/attn/MatMul
# /blocks/blocks.2/attn/Softmax
# /blocks/blocks.2/attn/MatMul_1
# /blocks/blocks.2/attn/Transpose_2
# /blocks/blocks.2/attn/Reshape_1
# /blocks/blocks.2/Add
# /blocks/blocks.2/Add
# /blocks/blocks.2/Add
# /blocks/blocks.2/norm2/Sub
# /blocks/blocks.2/norm2/Sub
# /blocks/blocks.2/norm2/Pow
# /blocks/blocks.2/norm2/ReduceMean_1
# /blocks/blocks.2/norm2/Add
# /blocks/blocks.2/norm2/Div
# /blocks/blocks.2/norm2/Mul
# /blocks/blocks.2/norm2/Add_1
# /blocks/blocks.2/mlp/fc1/Add
# /blocks/blocks.2/mlp/fc1/Add
# /blocks/blocks.2/mlp/act/Div
# /blocks/blocks.2/mlp/act/Erf
# /blocks/blocks.2/mlp/act/Mul
# /blocks/blocks.2/mlp/act/Mul_1
# /blocks/blocks.2/Add_1
# /blocks/blocks.2/Add_1
# /blocks/blocks.2/Add_1
# /blocks/blocks.3/norm1/Sub
# /blocks/blocks.3/norm1/Sub
# /blocks/blocks.3/norm1/Pow
# /blocks/blocks.3/norm1/ReduceMean_1
# /blocks/blocks.3/norm1/Add
# /blocks/blocks.3/norm1/Div
# /blocks/blocks.3/norm1/Mul
# /blocks/blocks.3/norm1/Add_1
# /blocks/blocks.3/attn/qkv/Add
# /blocks/blocks.3/attn/Reshape
# /blocks/blocks.3/attn/Transpose
# /blocks/blocks.3/attn/Split
# /blocks/blocks.3/attn/Squeeze
# /blocks/blocks.3/attn/Squeeze
# /blocks/blocks.3/attn/Squeeze_1
# /blocks/blocks.3/attn/Shape
# /blocks/blocks.3/attn/Slice
# /blocks/blocks.3/attn/Cast
# /blocks/blocks.3/attn/Constant_7
# /blocks/blocks.3/attn/Div
# /blocks/blocks.3/attn/Div
# /blocks/blocks.3/attn/Transpose_1
# /blocks/blocks.3/attn/Mul
# /blocks/blocks.3/attn/MatMul
# /blocks/blocks.3/attn/Softmax
# /blocks/blocks.3/attn/MatMul_1
# /blocks/blocks.3/attn/Transpose_2
# /blocks/blocks.3/attn/Reshape_1
# /blocks/blocks.3/Add
# /blocks/blocks.3/Add
# /blocks/blocks.3/Add
# /blocks/blocks.3/norm2/Sub
# /blocks/blocks.3/norm2/Sub
# /blocks/blocks.3/norm2/Pow
# /blocks/blocks.3/norm2/ReduceMean_1
# /blocks/blocks.3/norm2/Add
# /blocks/blocks.3/norm2/Div
# /blocks/blocks.3/norm2/Mul
# /blocks/blocks.3/norm2/Add_1
# /blocks/blocks.3/mlp/fc1/Add
# /blocks/blocks.3/mlp/fc1/Add
# /blocks/blocks.3/mlp/act/Div
# /blocks/blocks.3/mlp/act/Erf
# /blocks/blocks.3/mlp/act/Mul
# /blocks/blocks.3/mlp/act/Mul_1
# /blocks/blocks.3/Add_1
# /blocks/blocks.3/Add_1
# /blocks/blocks.3/Add_1
# /blocks/blocks.4/norm1/Sub
# /blocks/blocks.4/norm1/Sub
# /blocks/blocks.4/norm1/Pow
# /blocks/blocks.4/norm1/ReduceMean_1
# /blocks/blocks.4/norm1/Add
# /blocks/blocks.4/norm1/Div
# /blocks/blocks.4/norm1/Mul
# /blocks/blocks.4/norm1/Add_1
# /blocks/blocks.4/attn/qkv/Add
# /blocks/blocks.4/attn/Reshape
# /blocks/blocks.4/attn/Transpose
# /blocks/blocks.4/attn/Split
# /blocks/blocks.4/attn/Squeeze
# /blocks/blocks.4/attn/Squeeze
# /blocks/blocks.4/attn/Squeeze_1
# /blocks/blocks.4/attn/Shape
# /blocks/blocks.4/attn/Slice
# /blocks/blocks.4/attn/Cast
# /blocks/blocks.4/attn/Constant_7
# /blocks/blocks.4/attn/Div
# /blocks/blocks.4/attn/Div
# /blocks/blocks.4/attn/Transpose_1
# /blocks/blocks.4/attn/Mul
# /blocks/blocks.4/attn/MatMul
# /blocks/blocks.4/attn/Softmax
# /blocks/blocks.4/attn/MatMul_1
# /blocks/blocks.4/attn/Transpose_2
# /blocks/blocks.4/attn/Reshape_1
# /blocks/blocks.4/Add
# /blocks/blocks.4/Add
# /blocks/blocks.4/Add
# /blocks/blocks.4/norm2/Sub
# /blocks/blocks.4/norm2/Sub
# /blocks/blocks.4/norm2/Pow
# /blocks/blocks.4/norm2/ReduceMean_1
# /blocks/blocks.4/norm2/Add
# /blocks/blocks.4/norm2/Div
# /blocks/blocks.4/norm2/Mul
# /blocks/blocks.4/norm2/Add_1
# /blocks/blocks.4/mlp/fc1/Add
# /blocks/blocks.4/mlp/fc1/Add
# /blocks/blocks.4/mlp/act/Div
# /blocks/blocks.4/mlp/act/Erf
# /blocks/blocks.4/mlp/act/Mul
# /blocks/blocks.4/mlp/act/Mul_1
# /blocks/blocks.4/Add_1
# /blocks/blocks.4/Add_1
# /blocks/blocks.4/Add_1
# /blocks/blocks.5/norm1/Sub
# /blocks/blocks.5/norm1/Sub
# /blocks/blocks.5/norm1/Pow
# /blocks/blocks.5/norm1/ReduceMean_1
# /blocks/blocks.5/norm1/Add
# /blocks/blocks.5/norm1/Div
# /blocks/blocks.5/norm1/Mul
# /blocks/blocks.5/norm1/Add_1
# /blocks/blocks.5/attn/qkv/Add
# /blocks/blocks.5/attn/Reshape
# /blocks/blocks.5/attn/Transpose
# /blocks/blocks.5/attn/Split
# /blocks/blocks.5/attn/Squeeze
# /blocks/blocks.5/attn/Squeeze
# /blocks/blocks.5/attn/Squeeze_1
# /blocks/blocks.5/attn/Shape
# /blocks/blocks.5/attn/Slice
# /blocks/blocks.5/attn/Cast
# /blocks/blocks.5/attn/Constant_7
# /blocks/blocks.5/attn/Div
# /blocks/blocks.5/attn/Div
# /blocks/blocks.5/attn/Transpose_1
# /blocks/blocks.5/attn/Mul
# /blocks/blocks.5/attn/MatMul
# /blocks/blocks.5/attn/Softmax
# /blocks/blocks.5/attn/MatMul_1
# /blocks/blocks.5/attn/Transpose_2
# /blocks/blocks.5/attn/Reshape_1
# /blocks/blocks.5/Add
# /blocks/blocks.5/Add
# /blocks/blocks.5/Add
# /blocks/blocks.5/norm2/Sub
# /blocks/blocks.5/norm2/Sub
# /blocks/blocks.5/norm2/Pow
# /blocks/blocks.5/norm2/ReduceMean_1
# /blocks/blocks.5/norm2/Add
# /blocks/blocks.5/norm2/Div
# /blocks/blocks.5/norm2/Mul
# /blocks/blocks.5/norm2/Add_1
# /blocks/blocks.5/mlp/fc1/Add
# /blocks/blocks.5/mlp/fc1/Add
# /blocks/blocks.5/mlp/act/Div
# /blocks/blocks.5/mlp/act/Erf
# /blocks/blocks.5/mlp/act/Mul
# /blocks/blocks.5/mlp/act/Mul_1
# /blocks/blocks.5/Add_1
# /blocks/blocks.5/Add_1
# /blocks/blocks.5/Add_1
# /blocks/blocks.6/norm1/Sub
# /blocks/blocks.6/norm1/Sub
# /blocks/blocks.6/norm1/Pow
# /blocks/blocks.6/norm1/ReduceMean_1
# /blocks/blocks.6/norm1/Add
# /blocks/blocks.6/norm1/Div
# /blocks/blocks.6/norm1/Mul
# /blocks/blocks.6/norm1/Add_1
# /blocks/blocks.6/attn/qkv/Add
# /blocks/blocks.6/attn/Reshape
# /blocks/blocks.6/attn/Transpose
# /blocks/blocks.6/attn/Split
# /blocks/blocks.6/attn/Squeeze
# /blocks/blocks.6/attn/Squeeze
# /blocks/blocks.6/attn/Squeeze_1
# /blocks/blocks.6/attn/Shape
# /blocks/blocks.6/attn/Slice
# /blocks/blocks.6/attn/Cast
# /blocks/blocks.6/attn/Constant_7
# /blocks/blocks.6/attn/Div
# /blocks/blocks.6/attn/Div
# /blocks/blocks.6/attn/Transpose_1
# /blocks/blocks.6/attn/Mul
# /blocks/blocks.6/attn/MatMul
# /blocks/blocks.6/attn/Softmax
# /blocks/blocks.6/attn/MatMul_1
# /blocks/blocks.6/attn/Transpose_2
# /blocks/blocks.6/attn/Reshape_1
# /blocks/blocks.6/Add
# /blocks/blocks.6/Add
# /blocks/blocks.6/Add
# /blocks/blocks.6/norm2/Sub
# /blocks/blocks.6/norm2/Sub
# /blocks/blocks.6/norm2/Pow
# /blocks/blocks.6/norm2/ReduceMean_1
# /blocks/blocks.6/norm2/Add
# /blocks/blocks.6/norm2/Div
# /blocks/blocks.6/norm2/Mul
# /blocks/blocks.6/norm2/Add_1
# /blocks/blocks.6/mlp/fc1/Add
# /blocks/blocks.6/mlp/fc1/Add
# /blocks/blocks.6/mlp/act/Div
# /blocks/blocks.6/mlp/act/Erf
# /blocks/blocks.6/mlp/act/Mul
# /blocks/blocks.6/mlp/act/Mul_1
# /blocks/blocks.6/Add_1
# /blocks/blocks.6/Add_1
# /blocks/blocks.6/Add_1
# /blocks/blocks.7/norm1/Sub
# /blocks/blocks.7/norm1/Sub
# /blocks/blocks.7/norm1/Pow
# /blocks/blocks.7/norm1/ReduceMean_1
# /blocks/blocks.7/norm1/Add
# /blocks/blocks.7/norm1/Div
# /blocks/blocks.7/norm1/Mul
# /blocks/blocks.7/norm1/Add_1
# /blocks/blocks.7/attn/qkv/Add
# /blocks/blocks.7/attn/Reshape
# /blocks/blocks.7/attn/Transpose
# /blocks/blocks.7/attn/Split
# /blocks/blocks.7/attn/Squeeze
# /blocks/blocks.7/attn/Squeeze
# /blocks/blocks.7/attn/Squeeze_1
# /blocks/blocks.7/attn/Shape
# /blocks/blocks.7/attn/Slice
# /blocks/blocks.7/attn/Cast
# /blocks/blocks.7/attn/Constant_7
# /blocks/blocks.7/attn/Div
# /blocks/blocks.7/attn/Div
# /blocks/blocks.7/attn/Transpose_1
# /blocks/blocks.7/attn/Mul
# /blocks/blocks.7/attn/MatMul
# /blocks/blocks.7/attn/Softmax
# /blocks/blocks.7/attn/MatMul_1
# /blocks/blocks.7/attn/Transpose_2
# /blocks/blocks.7/attn/Reshape_1
# /blocks/blocks.7/Add
# /blocks/blocks.7/Add
# /blocks/blocks.7/Add
# /blocks/blocks.7/norm2/Sub
# /blocks/blocks.7/norm2/Sub
# /blocks/blocks.7/norm2/Pow
# /blocks/blocks.7/norm2/ReduceMean_1
# /blocks/blocks.7/norm2/Add
# /blocks/blocks.7/norm2/Div
# /blocks/blocks.7/norm2/Mul
# /blocks/blocks.7/norm2/Add_1
# /blocks/blocks.7/mlp/fc1/Add
# /blocks/blocks.7/mlp/fc1/Add
# /blocks/blocks.7/mlp/act/Div
# /blocks/blocks.7/mlp/act/Erf
# /blocks/blocks.7/mlp/act/Mul
# /blocks/blocks.7/mlp/act/Mul_1
# /blocks/blocks.7/Add_1
# /blocks/blocks.7/Add_1
# /blocks/blocks.7/Add_1
# /blocks/blocks.8/norm1/Sub
# /blocks/blocks.8/norm1/Sub
# /blocks/blocks.8/norm1/Pow
# /blocks/blocks.8/norm1/ReduceMean_1
# /blocks/blocks.8/norm1/Add
# /blocks/blocks.8/norm1/Div
# /blocks/blocks.8/norm1/Mul
# /blocks/blocks.8/norm1/Add_1
# /blocks/blocks.8/attn/qkv/Add
# /blocks/blocks.8/attn/Reshape
# /blocks/blocks.8/attn/Transpose
# /blocks/blocks.8/attn/Split
# /blocks/blocks.8/attn/Squeeze
# /blocks/blocks.8/attn/Squeeze
# /blocks/blocks.8/attn/Squeeze_1
# /blocks/blocks.8/attn/Shape
# /blocks/blocks.8/attn/Slice
# /blocks/blocks.8/attn/Cast
# /blocks/blocks.8/attn/Constant_7
# /blocks/blocks.8/attn/Div
# /blocks/blocks.8/attn/Div
# /blocks/blocks.8/attn/Transpose_1
# /blocks/blocks.8/attn/Mul
# /blocks/blocks.8/attn/MatMul
# /blocks/blocks.8/attn/Softmax
# /blocks/blocks.8/attn/MatMul_1
# /blocks/blocks.8/attn/Transpose_2
# /blocks/blocks.8/attn/Reshape_1
# /blocks/blocks.8/Add
# /blocks/blocks.8/Add
# /blocks/blocks.8/Add
# /blocks/blocks.8/norm2/Sub
# /blocks/blocks.8/norm2/Sub
# /blocks/blocks.8/norm2/Pow
# /blocks/blocks.8/norm2/ReduceMean_1
# /blocks/blocks.8/norm2/Add
# /blocks/blocks.8/norm2/Div
# /blocks/blocks.8/norm2/Mul
# /blocks/blocks.8/norm2/Add_1
# /blocks/blocks.8/mlp/fc1/Add
# /blocks/blocks.8/mlp/fc1/Add
# /blocks/blocks.8/mlp/act/Div
# /blocks/blocks.8/mlp/act/Erf
# /blocks/blocks.8/mlp/act/Mul
# /blocks/blocks.8/mlp/act/Mul_1
# /blocks/blocks.8/Add_1
# /blocks/blocks.8/Add_1
# /blocks/blocks.8/Add_1
# /blocks/blocks.9/norm1/Sub
# /blocks/blocks.9/norm1/Sub
# /blocks/blocks.9/norm1/Pow
# /blocks/blocks.9/norm1/ReduceMean_1
# /blocks/blocks.9/norm1/Add
# /blocks/blocks.9/norm1/Div
# /blocks/blocks.9/norm1/Mul
# /blocks/blocks.9/norm1/Add_1
# /blocks/blocks.9/attn/qkv/Add
# /blocks/blocks.9/attn/Reshape
# /blocks/blocks.9/attn/Transpose
# /blocks/blocks.9/attn/Split
# /blocks/blocks.9/attn/Squeeze
# /blocks/blocks.9/attn/Squeeze
# /blocks/blocks.9/attn/Squeeze_1
# /blocks/blocks.9/attn/Shape
# /blocks/blocks.9/attn/Slice
# /blocks/blocks.9/attn/Cast
# /blocks/blocks.9/attn/Constant_7
# /blocks/blocks.9/attn/Div
# /blocks/blocks.9/attn/Div
# /blocks/blocks.9/attn/Transpose_1
# /blocks/blocks.9/attn/Mul
# /blocks/blocks.9/attn/MatMul
# /blocks/blocks.9/attn/Softmax
# /blocks/blocks.9/attn/MatMul_1
# /blocks/blocks.9/attn/Transpose_2
# /blocks/blocks.9/attn/Reshape_1
# /blocks/blocks.9/Add
# /blocks/blocks.9/Add
# /blocks/blocks.9/Add
# /blocks/blocks.9/norm2/Sub
# /blocks/blocks.9/norm2/Sub
# /blocks/blocks.9/norm2/Pow
# /blocks/blocks.9/norm2/ReduceMean_1
# /blocks/blocks.9/norm2/Add
# /blocks/blocks.9/norm2/Div
# /blocks/blocks.9/norm2/Mul
# /blocks/blocks.9/norm2/Add_1
# /blocks/blocks.9/mlp/fc1/Add
# /blocks/blocks.9/mlp/fc1/Add
# /blocks/blocks.9/mlp/act/Div
# /blocks/blocks.9/mlp/act/Erf
# /blocks/blocks.9/mlp/act/Mul
# /blocks/blocks.9/mlp/act/Mul_1
# /blocks/blocks.9/Add_1
# /blocks/blocks.9/Add_1
# /blocks/blocks.9/Add_1
# /blocks/blocks.10/norm1/Sub
# /blocks/blocks.10/norm1/Sub
# /blocks/blocks.10/norm1/Pow
# /blocks/blocks.10/norm1/ReduceMean_1
# /blocks/blocks.10/norm1/Add
# /blocks/blocks.10/norm1/Div
# /blocks/blocks.10/norm1/Mul
# /blocks/blocks.10/norm1/Add_1
# /blocks/blocks.10/attn/qkv/Add
# /blocks/blocks.10/attn/Reshape
# /blocks/blocks.10/attn/Transpose
# /blocks/blocks.10/attn/Split
# /blocks/blocks.10/attn/Squeeze
# /blocks/blocks.10/attn/Squeeze
# /blocks/blocks.10/attn/Squeeze_1
# /blocks/blocks.10/attn/Shape
# /blocks/blocks.10/attn/Slice
# /blocks/blocks.10/attn/Cast
# /blocks/blocks.10/attn/Constant_7
# /blocks/blocks.10/attn/Div
# /blocks/blocks.10/attn/Div
# /blocks/blocks.10/attn/Transpose_1
# /blocks/blocks.10/attn/Mul
# /blocks/blocks.10/attn/MatMul
# /blocks/blocks.10/attn/Softmax
# /blocks/blocks.10/attn/MatMul_1
# /blocks/blocks.10/attn/Transpose_2
# /blocks/blocks.10/attn/Reshape_1
# /blocks/blocks.10/Add
# /blocks/blocks.10/Add
# /blocks/blocks.10/Add
# /blocks/blocks.10/norm2/Sub
# /blocks/blocks.10/norm2/Sub
# /blocks/blocks.10/norm2/Pow
# /blocks/blocks.10/norm2/ReduceMean_1
# /blocks/blocks.10/norm2/Add
# /blocks/blocks.10/norm2/Div
# /blocks/blocks.10/norm2/Mul
# /blocks/blocks.10/norm2/Add_1
# /blocks/blocks.10/mlp/fc1/Add
# /blocks/blocks.10/mlp/fc1/Add
# /blocks/blocks.10/mlp/act/Div
# /blocks/blocks.10/mlp/act/Erf
# /blocks/blocks.10/mlp/act/Mul
# /blocks/blocks.10/mlp/act/Mul_1
# /blocks/blocks.10/Add_1
# /blocks/blocks.10/Add_1
# /blocks/blocks.10/Add_1
# /blocks/blocks.11/norm1/Sub
# /blocks/blocks.11/norm1/Sub
# /blocks/blocks.11/norm1/Pow
# /blocks/blocks.11/norm1/ReduceMean_1
# /blocks/blocks.11/norm1/Add
# /blocks/blocks.11/norm1/Div
# /blocks/blocks.11/norm1/Mul
# /blocks/blocks.11/norm1/Add_1
# /blocks/blocks.11/attn/qkv/Add
# /blocks/blocks.11/attn/Reshape
# /blocks/blocks.11/attn/Transpose
# /blocks/blocks.11/attn/Split
# /blocks/blocks.11/attn/Squeeze
# /blocks/blocks.11/attn/Squeeze
# /blocks/blocks.11/attn/Squeeze_1
# /blocks/blocks.11/attn/Shape
# /blocks/blocks.11/attn/Slice
# /blocks/blocks.11/attn/Cast
# /blocks/blocks.11/attn/Constant_7
# /blocks/blocks.11/attn/Div
# /blocks/blocks.11/attn/Div
# /blocks/blocks.11/attn/Transpose_1
# /blocks/blocks.11/attn/Mul
# /blocks/blocks.11/attn/MatMul
# /blocks/blocks.11/attn/Softmax
# /blocks/blocks.11/attn/MatMul_1
# /blocks/blocks.11/attn/Transpose_2
# /blocks/blocks.11/attn/Reshape_1
# /blocks/blocks.11/Add
# /blocks/blocks.11/Add
# /blocks/blocks.11/Add
# /blocks/blocks.11/norm2/Sub
# /blocks/blocks.11/norm2/Sub
# /blocks/blocks.11/norm2/Pow
# /blocks/blocks.11/norm2/ReduceMean_1
# /blocks/blocks.11/norm2/Add
# /blocks/blocks.11/norm2/Div
# /blocks/blocks.11/norm2/Mul
# /blocks/blocks.11/norm2/Add_1
# /blocks/blocks.11/mlp/fc1/Add
# /blocks/blocks.11/mlp/fc1/Add
# /blocks/blocks.11/mlp/act/Div
# /blocks/blocks.11/mlp/act/Erf
# /blocks/blocks.11/mlp/act/Mul
# /blocks/blocks.11/mlp/act/Mul_1
# /blocks/blocks.11/Add_1
# /blocks/blocks.11/Add_1
# /norm/Sub
# /norm/Sub
# /norm/Pow
# /norm/ReduceMean_1
# /norm/Add
# /norm/Div
# /norm/Mul
# /norm/Add_1
# /Gather

# %%
# Model TVM with quant int8
validate(model, val_loader_sub, 'vit_base_patch16_224', ONNX = True, sample_size = 50, quant = 'int8', TVM = True)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Single Inference Runtime: 2.2313 seconds
# Top 1 Accuracy : 86.90%
# Top 5 Accuracy : 96.60%

# %%
# Model TVM with fp16
validate(model, val_loader_sub, 'vit_base_patch16_224', ONNX = True, sample_size = 50, quant = 'fp16', TVM = True)
# Out:
# 2024-04-06 14:13:23.062272959 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.0/attn/Sqrt'
# 2024-04-06 14:13:23.062549787 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.1/attn/Sqrt'
# 2024-04-06 14:13:23.062802720 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.2/attn/Sqrt'
# 2024-04-06 14:13:23.063042316 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.3/attn/Sqrt'
# 2024-04-06 14:13:23.063286738 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.4/attn/Sqrt'
# 2024-04-06 14:13:23.063523432 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.5/attn/Sqrt'
# 2024-04-06 14:13:23.063755301 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.6/attn/Sqrt'
# 2024-04-06 14:13:23.064006672 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.7/attn/Sqrt'
# 2024-04-06 14:13:23.064248946 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.8/attn/Sqrt'
# 2024-04-06 14:13:23.064483225 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.9/attn/Sqrt'
# 2024-04-06 14:13:23.064715752 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.10/attn/Sqrt'
# 2024-04-06 14:13:23.064962983 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.11/attn/Sqrt'
# 2024-04-06 14:13:23.090740771 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.11/attn/Sqrt'
# 2024-04-06 14:13:23.098046072 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.11/attn/Sqrt'
# 2024-04-06 14:13:23.105248428 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.11/attn/Sqrt'
# 2024-04-06 14:13:23.112403171 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.11/attn/Sqrt'
# 2024-04-06 14:13:23.119544119 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.11/attn/Sqrt'
# 2024-04-06 14:13:23.126892330 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.11/attn/Sqrt'
# 2024-04-06 14:13:23.133991429 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.11/attn/Sqrt'
# 2024-04-06 14:13:23.141194082 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.11/attn/Sqrt'
# 2024-04-06 14:13:23.148298669 [W:onnxruntime:, constant_folding.cc:269 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sqrt node '/blocks/blocks.11/attn/Sqrt'
#   0%|          | 0/1000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TVMError                                  Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Model TVM with fp16
# ----> 2 validate(model, val_loader_sub, 'vit_base_patch16_224', ONNX = True, sample_size = 50, quant = 'fp16', TVM = True)
#
# Cell In[7], line 54, in validate(model, val_loader, model_name, ONNX, quant, sample_size, quant_invest, TVM)
#      52     inputs = tvm.nd.array(inputs.astype("float32"))
#      53     start_time = time.time()
# ---> 54     outputs = [executor(inputs).numpy()]
#      55     end_time = time.time()
#      57 else:
#
# File /opt/conda/lib/python3.10/site-packages/tvm/relay/build_module.py:537, in GraphExecutor._make_executor.<locals>._graph_wrapper(*args, **kwargs)
#     535 # Create map of inputs.
#     536 for i, arg in enumerate(args):
# --> 537     gmodule.set_input(i, arg)
#     538 # Run the module, and fetch the output.
#     539 gmodule.run()
#
# File /opt/conda/lib/python3.10/site-packages/tvm/contrib/graph_executor.py:184, in GraphModule.set_input(self, key, value, **params)
#     182     if v is None:
#     183         raise RuntimeError("Could not find '%s' in graph's inputs" % key)
# --> 184     v.copyfrom(value)
#     186 if params:
#     187     # upload big arrays first to avoid memory issue in rpc mode
#     188     keys = list(params.keys())
#
# File /opt/conda/lib/python3.10/site-packages/tvm/runtime/ndarray.py:143, in NDArray.copyfrom(self, source_array)
#     130 """Perform a synchronous copy from the array.
#     131
#     132 Parameters
#    (...)
#     140     Reference to self.
#     141 """
#     142 if isinstance(source_array, NDArrayBase):
# --> 143     source_array.copyto(self)
#     144     return self
#     146 if not isinstance(source_array, np.ndarray):
#
# File /opt/conda/lib/python3.10/site-packages/tvm/runtime/ndarray.py:251, in NDArray.copyto(self, target, mem_scope)
#     240 """Copy array to target
#     241
#     242 Parameters
#    (...)
#     248     The memory scope of the array.
#     249 """
#     250 if isinstance(target, NDArrayBase):
# --> 251     return self._copyto(target)
#     252 if isinstance(target, Device):
#     253     res = empty(self.shape, self.dtype, target, mem_scope)
#
# File tvm/_ffi/_cython/./ndarray.pxi:99, in tvm._ffi._cy3.core.NDArrayBase._copyto()
#
# File tvm/_ffi/_cython/./base.pxi:181, in tvm._ffi._cy3.core.CHECK_CALL()
#
# TVMError: Traceback (most recent call last):
#   191: 0x00005c68b85dfd10
#   190: __libc_start_main
#   189: Py_BytesMain
#         at /usr/local/src/conda/python-3.10.13/Modules/main.c:1090
#   188: Py_RunMain
#         at /usr/local/src/conda/python-3.10.13/Modules/main.c:670
#   187: pymain_run_python
#         at /usr/local/src/conda/python-3.10.13/Modules/main.c:585
#   186: pymain_run_module
#         at /usr/local/src/conda/python-3.10.13/Modules/main.c:297
#   185: _PyFunction_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Objects/call.c:342
#   184: _PyEval_Vector
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5067
#   183: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   182: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:4213
#   181: call_function
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5893
#   180: PyObject_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:123
#   179: _PyObject_VectorcallTstate
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:114
#   178: _PyFunction_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Objects/call.c:342
#   177: _PyEval_Vector
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5067
#   176: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   175: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:4213
#   174: call_function
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5893
#   173: PyObject_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:123
#   172: _PyObject_VectorcallTstate
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:114
#   171: cfunction_vectorcall_FASTCALL
#         at /usr/local/src/conda/python-3.10.13/Objects/methodobject.c:430
#   170: builtin_exec
#         at /usr/local/src/conda/python-3.10.13/Python/clinic/bltinmodule.c.h:371
#   169: builtin_exec_impl
#         at /usr/local/src/conda/python-3.10.13/Python/bltinmodule.c:1058
#   168: PyEval_EvalCode
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:1134
#   167: _PyEval_Vector
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5067
#   166: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   165: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:4181
#   164: call_function
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5893
#   163: PyObject_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:123
#   162: _PyObject_VectorcallTstate
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:114
#   161: method_vectorcall
#         at /usr/local/src/conda/python-3.10.13/Objects/classobject.c:53
#   160: _PyObject_VectorcallTstate
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:114
#   159: _PyFunction_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Objects/call.c:342
#   158: _PyEval_Vector
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5067
#   157: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   156: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:4198
#   155: call_function
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5893
#   154: PyObject_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:123
#   153: _PyObject_VectorcallTstate
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:114
#   152: _PyFunction_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Objects/call.c:342
#   151: _PyEval_Vector
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5067
#   150: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   149: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:4198
#   148: call_function
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5893
#   147: PyObject_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:123
#   146: _PyObject_VectorcallTstate
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:114
#   145: _PyFunction_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Objects/call.c:342
#   144: _PyEval_Vector
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5067
#   143: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   142: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:4198
#   141: call_function
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5893
#   140: PyObject_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:123
#   139: _PyObject_VectorcallTstate
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:114
#   138: _PyFunction_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Objects/call.c:342
#   137: _PyEval_Vector
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5067
#   136: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   135: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:4198
#   134: call_function
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5893
#   133: PyObject_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:123
#   132: _PyObject_VectorcallTstate
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:114
#   131: _PyFunction_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Objects/call.c:342
#   130: _PyEval_Vector
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5067
#   129: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   128: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:4198
#   127: call_function
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5893
#   126: PyObject_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:123
#   125: _PyObject_VectorcallTstate
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:114
#   124: _PyFunction_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Objects/call.c:342
#   123: _PyEval_Vector
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5067
#   122: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   121: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:4277
#   120: do_call_core
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5917
#   119: cfunction_vectorcall_FASTCALL_KEYWORDS
#         at /usr/local/src/conda/python-3.10.13/Objects/methodobject.c:446
#   118: context_run
#         at /usr/local/src/conda/python-3.10.13/Python/context.c:665
#   117: _PyObject_VectorcallTstate
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:114
#   116: cfunction_vectorcall_O
#         at /usr/local/src/conda/python-3.10.13/Objects/methodobject.c:516
#   115: task_step
#         at /usr/local/src/conda/python-3.10.13/Modules/_asynciomodule.c:2950
#   114: task_step_impl
#         at /usr/local/src/conda/python-3.10.13/Modules/_asynciomodule.c:2653
#   113: gen_send_ex2
#         at /usr/local/src/conda/python-3.10.13/Objects/genobject.c:213
#   112: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   111: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:2586
#   110: gen_send_ex2
#         at /usr/local/src/conda/python-3.10.13/Objects/genobject.c:213
#   109: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   108: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:2586
#   107: gen_send_ex2
#         at /usr/local/src/conda/python-3.10.13/Objects/genobject.c:213
#   106: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   105: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:2586
#   104: gen_send_ex2
#         at /usr/local/src/conda/python-3.10.13/Objects/genobject.c:213
#   103: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   102: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:2586
#   101: gen_send_ex2
#         at /usr/local/src/conda/python-3.10.13/Objects/genobject.c:213
#   100: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   99: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:4231
#   98: call_function
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5893
#   97: PyObject_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:123
#   96: _PyObject_VectorcallTstate
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:114
#   95: method_vectorcall
#         at /usr/local/src/conda/python-3.10.13/Objects/classobject.c:53
#   94: _PyObject_VectorcallTstate
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:114
#   93: _PyFunction_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Objects/call.c:342
#   92: _PyEval_Vector
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5067
#   91: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   90: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:4277
#   89: do_call_core
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5945
#   88: PyObject_Call
#         at /usr/local/src/conda/python-3.10.13/Objects/call.c:317
#   87: _PyObject_Call
#         at /usr/local/src/conda/python-3.10.13/Objects/call.c:290
#   86: PyVectorcall_Call
#         at /usr/local/src/conda/python-3.10.13/Objects/call.c:267
#   85: method_vectorcall
#         at /usr/local/src/conda/python-3.10.13/Objects/classobject.c:53
#   84: _PyObject_VectorcallTstate
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:114
#   83: _PyFunction_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Objects/call.c:342
#   82: _PyEval_Vector
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5067
#   81: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   80: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:4198
#   79: call_function
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5893
#   78: PyObject_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:123
#   77: _PyObject_VectorcallTstate
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:114
#   76: _PyFunction_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Objects/call.c:342
#   75: _PyEval_Vector
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5067
#   74: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   73: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:4213
#   72: call_function
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5893
#   71: PyObject_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:123
#   70: _PyObject_VectorcallTstate
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:114
#   69: _PyFunction_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Objects/call.c:342
#   68: _PyEval_Vector
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5067
#   67: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   66: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:4198
#   65: call_function
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5893
#   64: PyObject_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:123
#   63: _PyObject_VectorcallTstate
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:114
#   62: method_vectorcall_O
#         at /usr/local/src/conda/python-3.10.13/Objects/descrobject.c:460
#   61: gen_send_ex
#         at /usr/local/src/conda/python-3.10.13/Objects/genobject.c:279
#   60: gen_send_ex2
#         at /usr/local/src/conda/python-3.10.13/Objects/genobject.c:213
#   59: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   58: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:2586
#   57: gen_send_ex2
#         at /usr/local/src/conda/python-3.10.13/Objects/genobject.c:213
#   56: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   55: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:2586
#   54: gen_send_ex2
#         at /usr/local/src/conda/python-3.10.13/Objects/genobject.c:213
#   53: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   52: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:4213
#   51: call_function
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5893
#   50: PyObject_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:123
#   49: _PyObject_VectorcallTstate
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:114
#   48: cfunction_vectorcall_FASTCALL
#         at /usr/local/src/conda/python-3.10.13/Objects/methodobject.c:430
#   47: builtin_exec
#         at /usr/local/src/conda/python-3.10.13/Python/clinic/bltinmodule.c.h:371
#   46: builtin_exec_impl
#         at /usr/local/src/conda/python-3.10.13/Python/bltinmodule.c:1058
#   45: PyEval_EvalCode
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:1134
#   44: _PyEval_Vector
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5067
#   43: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   42: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:4231
#   41: call_function
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5893
#   40: PyObject_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:123
#   39: _PyObject_VectorcallTstate
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:114
#   38: _PyFunction_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Objects/call.c:342
#   37: _PyEval_Vector
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5067
#   36: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   35: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:4213
#   34: call_function
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5893
#   33: PyObject_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:123
#   32: _PyObject_VectorcallTstate
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:114
#   31: _PyFunction_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Objects/call.c:342
#   30: _PyEval_Vector
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5067
#   29: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   28: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:4198
#   27: call_function
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5893
#   26: PyObject_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:123
#   25: _PyObject_VectorcallTstate
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:114
#   24: _PyFunction_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Objects/call.c:342
#   23: _PyEval_Vector
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5067
#   22: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   21: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:4198
#   20: call_function
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5893
#   19: PyObject_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:123
#   18: _PyObject_VectorcallTstate
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:114
#   17: _PyFunction_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Objects/call.c:342
#   16: _PyEval_Vector
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5067
#   15: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   14: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:4198
#   13: call_function
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5893
#   12: PyObject_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:123
#   11: _PyObject_VectorcallTstate
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:114
#   10: _PyFunction_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Objects/call.c:342
#   9: _PyEval_Vector
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5067
#   8: _PyEval_EvalFrame
#         at /usr/local/src/conda/python-3.10.13/Include/internal/pycore_ceval.h:46
#   7: _PyEval_EvalFrameDefault
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:4198
#   6: call_function
#         at /usr/local/src/conda/python-3.10.13/Python/ceval.c:5893
#   5: PyObject_Vectorcall
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:123
#   4: _PyObject_VectorcallTstate
#         at /usr/local/src/conda/python-3.10.13/Include/cpython/abstract.h:114
#   3: method_vectorcall_O
#         at /usr/local/src/conda/python-3.10.13/Objects/descrobject.c:460
#   2: __pyx_pw_3tvm_4_ffi_4_cy3_4core_11NDArrayBase_5_copyto(_object*, _object*)
#   1: TVMArrayCopyFromTo
#   0: tvm::runtime::NDArray::CopyFromTo(DLTensor const*, DLTensor*, void*)
#   File "/workspace/tvm/src/runtime/ndarray.cc", line 270
# TVMError:
# ---------------------------------------------------------------
# An error occurred during the execution of TVM.
# For more information, please see: https://tvm.apache.org/docs/errors.html
# ---------------------------------------------------------------
#
#   Check failed: from_size == to_size (602112 vs. 301056) : TVMArrayCopyFromTo: The size must exactly match

# %%
# import torch
# import torchvision.models as models
# import urllib
# from PIL import Image
# from torchvision import transforms

# # Create an instance of the MaxViT-T model with pre-trained weights on ImageNet
# model = models.maxvit_t(weights='imagenet')

# # Define a preprocessing pipeline for the input image
# preprocess = transforms.Compose([
#     transforms.Resize(256),
#     transforms.CenterCrop(224),
#     transforms.ToTensor(),
#     transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
# ])

# # Load and preprocess an example image
# url, filename = ("https://github.com/pytorch/hub/raw/master/images/dog.jpg", "dog.jpg")
# urllib.request.urlretrieve(url, filename)
# input_image = Image.open(filename)
# input_tensor = preprocess(input_image)
# input_batch = input_tensor.unsqueeze(0)  # Add a batch dimension

# # Put the model in evaluation mode
# model.eval()

# # Perform inference using the pre-trained model
# with torch.no_grad():
#     output = model(input_batch)

# # Print the top 5 predicted classes
# _, indices = torch.sort(output, descending=True)
# imagenet_labels = urllib.request.urlopen("https://raw.githubusercontent.com/anishathalye/imagenet-simple-labels/master/imagenet-simple-labels.json")
# labels = [line.strip() for line in imagenet_labels.readlines()]
# percentage = torch.nn.functional.softmax(output, dim=1)[0] * 100
# for i in range(5):
#     print(labels[indices[0][i]], percentage[indices[0][i]].item())
